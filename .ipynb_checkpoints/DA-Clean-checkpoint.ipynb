# %%
# %load_ext autoreload
# %autoreload 2
from datasets import load_dataset
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay
import numpy as np
from scipy.sparse import hstack
import nltk as nltk
from nltk import word_tokenize          
from nltk.stem import WordNetLemmatizer 
from sklearn.feature_extraction.text import CountVectorizer
nltk.download('punkt')
nltk.download('wordnet')
nltk.download('vader_lexicon')
from nltk.sentiment.vader import SentimentIntensityAnalyzer
import matplotlib.pyplot as plt
import numpy as np
from gensim.utils import simple_preprocess
from gensim.parsing.preprocessing import STOPWORDS
from IPython.display import clear_output
import matplotlib.pyplot as plt
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\adnan\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\adnan\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\adnan\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %%
# Loading files
train_files = [
    'data/FiQA_ABSA_task1/task1_headline_ABSA_train.json',
    'data/FiQA_ABSA_task1/task1_post_ABSA_train.json'
]

# %%
## Loading data from JSON
import json

def load_fiqa_sa_from_json(json_files):
    train_text = []
    train_labels = []

    for file in json_files:
        with open(file, 'r', encoding='UTF-8') as handle:
            dataf = json.load(handle)
        dataf_text = [dataf[k]["sentence"] for k in dataf.keys()]
        train_text.extend(dataf_text)
        dataf_labels = [float(dataf[k]["info"][0]["sentiment_score"]) for k in dataf.keys()]
        train_labels.extend(dataf_labels)
    train_text = np.array(train_text)
    train_labels = np.array(train_labels)
    return train_text, train_labels


def threshold_scores(scores):
    """
    Convert sentiment scores to discrete labels.
    0 = negative.
    1 = neutral.
    2 = positive.
    """
    labels = []
    for score in scores:
        if score < -0.2:
            labels.append(0)
        elif score > 0.2:
            labels.append(2)
        else:
            labels.append(1)
            
    return np.array(labels)


all_text, all_labels = load_fiqa_sa_from_json(train_files)
    
print(f'Number of instances: {len(all_text)}')
print(f'Number of labels: {len(all_labels)}')

all_labels = threshold_scores(all_labels)
print(f'Number of negative labels: {np.sum(all_labels==0)}')
print(f'Number of neutral labels: {np.sum(all_labels==1)}')
print(f'Number of positive labels: {np.sum(all_labels==2)}')
# Out:
# Number of instances: 1111
# Number of labels: 1111
# Number of negative labels: 310
# Number of neutral labels: 195
# Number of positive labels: 606

# %%
# Split the data into training, validation, testing sets.

from sklearn.model_selection import train_test_split

# Split test data from training data
train_tweets, test_tweets, train_labels, test_labels = train_test_split(
    all_text, 
    all_labels, 
    test_size=0.2, 
    stratify=all_labels
)

# Split validation data from training data
train_tweets, val_documents, train_labels, val_labels = train_test_split(
    train_tweets, 
    train_labels, 
    test_size=0.2, 
    stratify=train_labels
)

print(f'Number of training instances = {len(train_tweets)}')
print(f'Number of validation instances = {len(val_documents)}')
print(f'Number of test instances = {len(test_tweets)}')
# Out:
# Number of training instances = 710
# Number of validation instances = 178
# Number of test instances = 223

# %%
# Print example tweet
print(f'What does one instance look like from the training set? \n\n{train_tweets[234]}')
print(f'...and here is its corresponding label \n\n{train_labels[234]}')
# Out:
# What does one instance look like from the training set?
#
# $AAPL iPhone shipments on track to exceed forecasts - MarketWatch https://t.co/2CXahJIX7d
# ...and here is its corresponding label
#
# 2

# %% [markdown]
# # 1. Preprocessing using  lemmatization
# We create a lemmatizer tokenizer that reduces words to their root forms. This reduces the vocabulary size.

# %%
# We create a lemmaTokenizer class that applies lemmatization when tokenizing.
class LemmaTokenizer(object):
    
    def __init__(self):
        self.wnl = WordNetLemmatizer()
        
    def __call__(self, tweets):
        return [self.wnl.lemmatize(self.wnl.lemmatize(self.wnl.lemmatize(tok, pos='n'), pos='v'), pos='a') for tok in word_tokenize(tweets)]

# %% [markdown]
# # 2.1 Using bi-grams + unigrams as feature
# We apply our tokenizer and set it to allow ngram features (both unigrams and bigrams).

# %%
vectorizer = CountVectorizer(tokenizer=LemmaTokenizer(), ngram_range=(1,2))
vectorizer.fit(train_tweets)
X_train = vectorizer.transform(train_tweets)
X_val = vectorizer.transform(val_documents)
X_test_tweets = vectorizer.transform(test_tweets)
# Let's look at some of the features.
print(list(vectorizer.vocabulary_)[:10])
# Out:
# C:\Users\adnan\anaconda3\envs\data_analytics\lib\site-packages\sklearn\feature_extraction\text.py:516: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   warnings.warn(
# ['update', '3-bp', 'settle', 'oil', 'spill-related', 'claim', 'with', 'halliburton', ',', 'transocean']

# %%
# Checking full vocabulary size:
print(f' Full vocabulary size: {len(vectorizer.vocabulary_)}')
vocabulary = vectorizer.vocabulary_
# Out:
#  Full vocabulary size: 10827

# %%
# Now let's fit our data to the model.
classifier = LogisticRegression()
classifier.fit(X_train, train_labels)
y_val_pred = classifier.predict(X_val)
cm = confusion_matrix(val_labels, y_val_pred)
cm_display = ConfusionMatrixDisplay(cm).plot()
print(classification_report(val_labels, y_val_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.70      0.46      0.55        50
#            1       0.40      0.19      0.26        31
#            2       0.68      0.91      0.78        97
#
#     accuracy                           0.66       178
#    macro avg       0.59      0.52      0.53       178
# weighted avg       0.63      0.66      0.62       178

# %% [markdown]
# # Using POS-NEG lexicon features

# %%
# instantiate analyzer
analyser = SentimentIntensityAnalyzer()
# fetch vocabulary
vocabulary = vectorizer.vocabulary_
# create empy holders for lexicon scores.
lexicon_pos_scores = np.zeros((1, len(vocabulary)))
lexicon_neg_scores = np.zeros((1, len(vocabulary)))

for i, term in enumerate(vocabulary):
    if term in analyser.lexicon and analyser.lexicon[term] > 0:
        lexicon_pos_scores[0, i] = 1
    elif term in analyser.lexicon and analyser.lexicon[term] < 0:
        lexicon_neg_scores[0, i] = 1

# %%
# This enables us to get the total positive and total negative counts for each set:
lexicon_pos_train = np.sum(X_train.multiply(lexicon_pos_scores), axis=1)
lexicon_pos_val = np.sum(X_val.multiply(lexicon_pos_scores), axis=1)
lexicon_pos_test = np.sum(X_test_tweets.multiply(lexicon_pos_scores), axis=1)

lexicon_neg_train = np.sum(X_train.multiply(lexicon_neg_scores), axis=1)
lexicon_neg_val = np.sum(X_val.multiply(lexicon_neg_scores), axis=1)
lexicon_neg_test = np.sum(X_test_tweets.multiply(lexicon_neg_scores), axis=1)

# %%
X_train = hstack((X_train, lexicon_pos_train, lexicon_neg_train))
X_val = hstack((X_val, lexicon_pos_val, lexicon_neg_val))
X_test_tweets = hstack((X_test_tweets, lexicon_pos_test, lexicon_neg_test))

# %%
classifier = LogisticRegression()
classifier.fit(X_train, train_labels)
y_val_pred = classifier.predict(X_val)
# Checking performance
cm = confusion_matrix(val_labels, y_val_pred)
cm_display = ConfusionMatrixDisplay(cm).plot()
print(classification_report(val_labels, y_val_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.69      0.48      0.56        50
#            1       0.43      0.19      0.27        31
#            2       0.67      0.90      0.77        97
#
#     accuracy                           0.66       178
#    macro avg       0.60      0.52      0.53       178
# weighted avg       0.63      0.66      0.62       178

# %%
# Key part is investigating the errors by looking at the actual values, so let's do that:
error_indexes = y_val_pred != val_labels  # let's compare predictions to true values for labels

# get the tweets where the classifier made an error:
tweets_err = np.array(val_documents)[error_indexes]

pred_err = y_val_pred[error_indexes]
true_err = np.array(val_labels)[error_indexes]

for i in range(10):
    print(f'Tweet: {tweets_err[i]}; true label = {true_err[i]}, prediction = {pred_err[i]}.')
# Out:
# Tweet: $AAPL bounce right now has no vol, more vol when it slid; true label = 1, prediction = 2.
# Tweet: #Apple breaks major support, here are some levels to watch - http://stks.co/jRmW $AAPL $QQQ; true label = 0, prediction = 2.
# Tweet: Sheryl Sandberg Sells 109,000 Shares of Facebook Inc $FB Stock https://t.co/3vXT7AMnpk via @RatingsNetwork; true label = 1, prediction = 2.
# Tweet: FTSE rallies off three-month low, boosted by StanChart, Sainsbury; true label = 2, prediction = 0.
# Tweet: Key level to watch in $FB for today is 25.53-- watching to see if it can hold as support http://stks.co/bOH4; true label = 1, prediction = 2.
# Tweet: NetApp downgraded by Macquarie to underperform. $22.00 PT. https://t.co/XCNgws0t4q $NTAP #NTAP via @RatingsNetwork; true label = 0, prediction = 2.
# Tweet: $AAPL Action into the close indicates that $AAPL probably hit a near term high.  Momentum slowing after a huge run.; true label = 1, prediction = 2.
# Tweet: Kingfisher takeover of Mr Bricolage could hit a brick wall; true label = 0, prediction = 2.
# Tweet: $JNK http://stks.co/2Fcm Does not want to go down... risk appetite still high; true label = 2, prediction = 0.
# Tweet: $VIPS similar pattern like beginning of May. Did u sell? Same now..will go up much higher after this drop.; true label = 2, prediction = 0.

# %% [markdown]
# # Performance on test set

# %%
# Let's test the performance on the test set.
y_test_pred = classifier.predict(X_test_tweets)
# Checking performance
cm = confusion_matrix(test_labels, y_test_pred)
cm_display = ConfusionMatrixDisplay(cm).plot()
print(classification_report(test_labels, y_test_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.76      0.52      0.62        62
#            1       0.62      0.21      0.31        39
#            2       0.65      0.90      0.76       122
#
#     accuracy                           0.67       223
#    macro avg       0.68      0.54      0.56       223
# weighted avg       0.68      0.67      0.64       223

# %% [markdown]
# # 4. Extracting topics using LDA

# %%
# First let's get another clean split of the data. 
from sklearn.model_selection import train_test_split

# Split test data from training data
train_tweets, test_tweets, train_labels, test_labels = train_test_split(
    all_text, 
    all_labels, 
    test_size=0.2, 
    stratify=all_labels
)

# Split validation data from training data
train_tweets, val_tweets, train_labels, val_labels = train_test_split(
    train_tweets, 
    train_labels, 
    test_size=0.2, 
    stratify=train_labels 
)

print(f'Number of training instances = {len(train_tweets)}')
print(f'Number of validation instances = {len(val_tweets)}')
print(f'Number of test instances = {len(test_tweets)}')
# Out:
# Number of training instances = 710
# Number of validation instances = 178
# Number of test instances = 223

# %%
 # We use the function below for tokenization. Does a number of things, including removing small words, deleting words with special chars,  changing uppercase to lowercase, and more.
def preprocess(text):
    final_results=[]
    for token in simple_preprocess(text) : 
        if token not in STOPWORDS:
            final_results.append(WordNetLemmatizer().lemmatize(token, 'v'))
    return final_results

# Create a list of preprocessed documents
processed = []
for doc in train_tweets:
    processed.append(preprocess(doc))
print(processed)
# Out:
# [['amzn', 'break'], ['aapl', 'short'], ['nflx', 'small', 'pos', 'short', 'wkly', 'put'], ['buy', 'jumbo', 'yielders', 'british', 'american', 'tobacco', 'plc', 'centrica', 'plc', 'john', 'wood', 'group', 'plc'], ['dgi', 'technical', 'alert', 'gilligan', 'island', 'buy', 'setup', 'stochastic', 'buy', 'signal', 'lizard', 'bullish', 'hammer', 'candlestick', 'wid', 'http', 'stks', 'nu'], ['yndx', 'price', 'stock', 'time', 'lower', 'annual', 'earn', 'resist', 'buy', 'sell'], ['onty', 'continue', 'base', 'debate', 'linger', 'ont', 'data', 'potential', 'catalyst', 'positive', 'stock', 'quickly', 'move', 'downside', 'limit'], ['qcor', 'add', 'share'], ['city', 'spirit', 'sink', 'diageo', 'come', 'short', 'sales', 'slide'], ['update', 'lloyds', 'cut', 'job', 'year', 'restructure', 'plan'], ['kep', 'break', 'market', 'pull', 'http', 'stks', 'cet'], ['primark', 'rack', 'happy', 'christmas', 'strong', 'sales'], ['tsla', 'love', 'type', 'article', 'ss', 'rise', 'day', 'hit', 'low', 'http', 'stks', 'qkr'], ['heat', 'yahoo', 'yhoo', 'wall', 'street', 'journal', 'https', 'jvji', 'bia'], ['british', 'american', 'tobacco', 'half', 'sales', 'hurt', 'currency', 'move'], ['royal', 'mail', 'share', 'price', 'rally', 'amid', 'positive', 'broker', 'comment'], ['acinvestorblog', 'spy', 'eod', 'run'], ['short', 'faz', 'know', 'mean', 'market', 'tank'], ['despite', 'sales', 'growth', 'uk', 'tesco', 'caution', 'recovery', 'bumpy'], ['tsla', 'look', 'good', 'love', 'base', 'action', 'let', 'rsi', 'breather', 'http', 'stks'], ['tripadvisor', 'jump', 'rumor', 'https', 'lwcdxmbr', 'trip'], ['dara', 'break'], ['update', 'engineer', 'firm', 'smiths', 'group', 'confirm', 'ceo', 'appointment'], ['googl', 'short', 'upper', 'bb', 'overbought'], ['intu', 'process', 'streamline', 'structure', 'especially', 'divestment', 'non', 'core', 'businesses', 'https', 'dr', 'banun'], ['amrn', 'bull', 'spread', 'range', 'july', 'jan', 'let', 'baby'], ['star', 'analyst', 'joe', 'wittine', 'longbow', 'research', 'reiterate', 'hold', 'rat', 'ntap'], ['take', 'endp', 'long', 'vwap', 'guide'], ['cover', 'small', 'mww', 'short', 'loss', 'flat', 'day', 'cash'], ['nvestor', 'soda', 'float', 'short', 'lol', 'http', 'stks', 'dfp'], ['aapl', 'http', 'stks', 'ldx', 'clear', 'descend', 'trend', 'line', 'buy', 'area'], ['update', 'cib', 'legal', 'general', 'sell', 'egyptian', 'life', 'joint', 'venture', 'axa'], ['morrisons', 'book', 'second', 'consecutive', 'quarter', 'sales', 'growth'], ['royal', 'mail', 'get', 'mix', 'bag', 'ofcom', 'postal', 'regulation', 'report'], ['ab', 'inbev', 'attack', 'sabmiller', 'bid', 'rebuffal'], ['starbucks', 'digital', 'strategy', 'drive', 'significant', 'growth', 'customer', 'loyalty', 'sbux', 'https', 'xk', 'lz', 'ui'], ['vxx', 'start', 'creep', 'spy', 'sit', 'near', 'hod'], ['spain', 'caixabank', 'expect', 'close', 'deal', 'banco', 'bpi'], ['tsla', 'yeah', 'let', 'lol'], ['ab', 'inbev', 'sell', 'sabmiller', 'stake', 'china', 'snow', 'beer'], ['spy', 'people', 'call', 'bearish', 'head', 'exit', 'maybe', 'crash', 'disturb'], ['rec_zakaria', 'monday', 'bull', 'stock', 'ticker', 'michael', 'jam', 'ent', 'pick', 'sbux', 'gvp', 'nke'], ['eln', 'long', 'congrats', 'hod'], ['doubt', 'grow', 'glaxosmithkline', 'bln', 'capital', 'return', 'plan'], ['update', 'astrazeneca', 'buy', 'zs', 'pharma', 'billion', 'pip', 'actelion'], ['gsk', 'novartis', 'complete', 'deal', 'reshape', 'drugmakers'], ['know', 'seat', 'sit', 'tsla', 'tesla', 'recall', 'model', 'cars', 'https', 'gwz', 'zc'], ['citrix', 'systems', 'ctxs', 'position', 'increase', 'mizuho', 'https', 'lkq', 'flp', 'sharestocknews'], ['iwm', 'relative', 'weakness', 'pretty', 'apparent', 'short', 'boat', 'get', 'prefer', 'boat', 'closer'], ['rt', 'acinvestorblog', 'aapl', 'track'], ['fbr', 'capital', 'reiterate', 'outperform', 'rat', 'brcm', 'price', 'target', 'friday'], ['astrazeneca', 'weigh', 'acerta', 'bid', 'secure', 'blood', 'cancer', 'drug'], ['spy', 'long', 'position'], ['micron', 'share', 'pound', 'fear', 'lo ...

# %%
from gensim.corpora import Dictionary
# create a dictionary of word<->id key/val pairs.
dictionary = Dictionary(processed) 
print(dictionary)

bow_corpus = [dictionary.doc2bow(doc) for doc in processed]
# Out:
# Dictionary(2333 unique tokens: ['amzn', 'break', 'aapl', 'short', 'nflx']...)

# %%
# Getting means of thetas

from gensim.matutils import any2sparse
from gensim.models import LdaModel

lda_model =  LdaModel(bow_corpus, 
                      num_topics=10, 
                      id2word=dictionary,                                    
                      passes=10,
                    ) 

def get_tweet_topic_dists(train_tweets, lda_model):
    thetas = []
    for i in range(len(train_tweets)):
        # Get the tweet
        unseen_tweet = train_tweets[i]

        # Preprocess for bag of words:
        bow_vector = dictionary.doc2bow(preprocess(unseen_tweet))

        # Let's get the topic distribution:
        theta_tweet = lda_model[bow_vector]

        thetas.append(theta_tweet)

    return thetas

thetas = get_tweet_topic_dists(train_tweets, lda_model)

# %%
# We will use colours to represent topics.
colours = ['blue', 'green', 'red', 'yellow', 'black', 'pink', 'purple',
           'orange',  'darkgreen',  'navy', 'crimson']

def convert_theta_sparse_to_dense_vector(theta_dist_sparse, num_topics):
    theta_dist = np.zeros(num_topics)  # an empty array
    
    # get active topics
    active_topics_for_dist, probs = map(list, zip(*theta_dist_sparse))
    
    # add to thetas_dist
    for i, topic in enumerate(active_topics_for_dist):
        if topic >= num_topics:
            break
            
        theta_dist[topic] = probs[i]
    
    return theta_dist

# Create barchart
def plot_theta(thetas, i, num_tweets, num_topics):
    plt.subplot(int((num_tweets+1)/2), 2, i+1)
    theta_dist = convert_theta_sparse_to_dense_vector(thetas[i], num_topics)
    plt.bar(x=np.arange(len(theta_dist)), height=theta_dist, color=colours, tick_label=np.arange(num_topics))

plt.figure(figsize=(20,15))

num_tweets = 10
num_topics = 10
counter = 0
for i, theta in enumerate(thetas):
    if (counter < 10):
        plot_theta(thetas, i, num_tweets, num_topics)
        counter +=1
plt.show()

# %%
# Merge arrays for later 
arr = train_tweets
arr_2 = train_labels

arrays = [arr,arr_2]
new_arr = np.stack(arrays, axis=1)
print(new_arr[new_arr[:,1] =='1'])
# Out:
# [['Should You Buy Jumbo Yielders British American Tobacco plc, Centrica PLC & John Wood Group PLC?'
#   '1']
#  ["Despite sales growth, UK's Tesco cautions recovery to be bumpy" '1']
#  ['UPDATE 1-Engineering firm Smiths Group confirms CEO appointment' '1']
#  ['UPDATE: CIB, Legal & General Sell Egyptian Life Joint Venture To AXA'
#   '1']
#  ['Royal Mail gets mixed bag from Ofcom postal regulation report' '1']
#  ['AB InBev attacks SABMiller bid rebuffal' '1']
#  ['$vxx starting to creep up while $spy sits near hod ...' '1']
#  ["AB InBev to Sell SABMiller Stake in China's Snow Beer" '1']
#  ['$SPY Less than 0.2% down and people are calling it bearish. Some heading for exits already. Maybe 1% down will be "the crash"? Disturbing!'
#   '1']
#  ['RT @ACInvestorBlog $AAPL still on track for $500' '1']
#  ['GlaxoSmithKline set to complete $20 billion Novartis asset swap next week'
#   '1']
#  ['$RIG whos ever pushing this is crazy, get ready for suspended dividend (turning into growth stock) blow out earnings, and major buyback, lol'
#   '1']
#  ['@saltwaternurse $INO can test 10 again in next few days. time to take some profits here. or hedge with puts.'
#   '1']
#  ["Whitbread boss Andy Harrison defends sales fall as 'just a blip'" '1']
#  ['Rio Tinto CEO says iron ore market at equilibrium' '1']
#  ['BG Group appoints new CEO one month early' '1']
#  ["SAB's Chairman Digs In With Board Divided on InBev Offer" '1']
#  ['$PAY 2nd time test of the 21.20-30 b/o zone.  Still not breaking out.  Moved my stop up to 20.80.'
#   '1']
#  ['MarketsBP promotes upstream boss to deputy CEO' '1']
#  ['CompaniesNew Aggreko CEO to reshape business, strip costs' '1']
#  ["My $DWA play up 6% today. I'm still skeptical. Will take profits. Not a time cheer"
#   '1']
#  ['FDA panel backs safety updates for AstraZeneca, Takeda drugs' '1']
#  ["$RUSS Don't catch falling knives, but I think an entry is coming soon on this"
#   '1']
#  ['CEOs of BPM, UBI meet Italy econ minister as M&A talk heats up' '1']
#  ["stole my tweet. really wouldn't be surprised if we took out 423 and pinned around it RT @totalguru We could possibly even see425 today $AAPL"
#   '1']
#  ['$SLW is down, but weekly $34 calls (-28.95%), .23 x .25 have 321 volume. Worth a chance here, jmho: http://stks.co/1Qfg'
#   '1']
#  ['UPDATE 1-BP shareholders back more disclosure on climate change risks'
#   '1']
#  ['After Barclays and Bank of America, Citigroup has blockchain in sight'
#   '1']
#  ['AB InBev offers SABMiller $3 billion breakup fee' '1']
#  ["$WGO's BoD was right to reject the offer. That company is low because of the economy, not because of any type of mismanagement or anything."
#   '1']
#  ["RBS Pays $1.7 Billion to Scrap U.K. Treasury's Dividend Rights" '1']
#  ['Standard Chartered Not Raising Capital Yet As Dividend Cut' '1']
#  ["UPDATE 5-SABMiller rejects AB InBev's $104 bln takeover approach" '1']
#  ['$AGN and $PYPL under pressure along with the market, however there were bullish options trades in both this morning https://t.co/9xG5W8nONT'
#   '1']
#  ['$AAPL 620 resistance area' '1']
#  ['Barclays poaches new chief operating officer Paul Compton from JP Morgan Chase'
#   '1']
#  ['InterContinental Hotels Denies Reports of Starwood Merger Talks' '1']
#  ["RT @jan $ARNA Don't think buyout rumor strong enough too be driving this up just yet...when it is this may fly like aapl...// fly how high?"
#   '1']
#  ["Morning Agenda: Shire's Deal for NPS" '1']
#  ['Tesco sells Blinkbox and broadband service to TalkTalk' '1']
#  ['$RAD All my charts are flashing oversold.' '1']
#  ['$PG Ackman making the big added efficiency argument. betting on operational imporvement in a huge conglomerate can go either way imo.'
#   '1']
#  ['HSBC shakes up board with two new business chiefs, three departures'
#   '1']
#  ['U.S. Debt Lures Schroders as ECB Depresses Rates' '1']
#  ['RT @StockTwits RT @fallondpicks Breadth Consolidates: After weeks of steady gains,advances in mkt breadth slowe... http://stks.co/2TrG $QQQ'
#   '1']
#  ['$MA http://stks.co/1CYN continues to consolidate / base here' '1']
#  ['Breakingviews: IAG can pay more for Aer Lingus' '1']
#  ["Should you buy Associated British Foods plc, Great Portland Estates plc and Dunelm Group plc following today's news?"
#   '1']
#  ['Philip Morris, BAT Sue Over Law Taking Branding Off Packs' '1']
#  ['easyJet expects resilient demand to withstand security fears' '1']
#  ['UPDATE: Barclays Expects Gain After Settling With Lehman Bros Trustee'
#   '1']
#  ['UPDATE 1-SABMiller 2nd-quarter underlying sales rise, forex impacts margins'
#   '1']
#  ['$QCOR a little pullback is fine but if this erases all of todays gains, I cannot believe the manipulation its capable of'
#   '1']
#  ['$YHOO fishy action. New party interested (DailyMail) bounce & retreats. Not short by any means, but action questions big up move. Thoughts?'
#   '1']
#  ['Tesco set to sell Kipa, Giraffe businesses - Sky News' '1']
#  ['Shire CEO steps up drive to get Baxalta board talking' '1']
#  ['Sainsbury CFO Rogers to Replace Home Retail CEO Walden' '1']
#  ['Analyst Views: Astrazeneca shares have seen recent volatility; what will 2015 ...'
#   '1']
#  ['Sanofi poaches AstraZeneca scientist as new research head' '1']
#  ['Johnson Matthey profit falls but dividend rises' '1']
#  ['Germanwings disaster will not affect image of budget air travel - easyJet'
#   '1']
#  ['$AAPL Taking out the shorts here, a punishing reminder not to spear the  strongest in the herd.'
#   '1']
#  ['$AAPL bounce right now has no vol, more vol when it slid' '1']
#  ['Randgold profit hit by poor gold price but dividend still increases'
#   '1']
#  ['$tsla X recall not a big deal... the problem is now they will have an excuse to guide way way lower...'
#   '1']
#  ['Why $TWTR is doomed in 1 chart $FB $GOOG  https://t.co/MpyLiReQjh https://t.co/nlcZawDoHP'
#   '1']
#  ['Irish Said Chasing Standard Chartered, RBS as Brexit Vote Nears' '1']
#  ['Coke dividend - 3%. Google dividend - 0%. For passive income Coke takes it. $GOOG $KO https://t.co/QBsoWjxOST'
#   '1']
#  ['Royal Mail turnaround proving expensive in tough UK market' '1']
#  ['CompaniesHoward Davies appointment as RBS director delayed' '1']
#  ['Tesco breaks its downward slide by cutting sales decline in half' '1']
#  ['$AAPL a new long IF 110.61 is broken. Targets are 112.19, 119.86 & 123.82. Bears must retake 102.77. $QQQ $NQ_F $NDX https://t.co/6l3m1wXChw'
#   '1']
#  ['New Credit Suisse boss faces stiff challenge in Asia' '1']
#  ['Diageo Sells Ryder Cup Venue Gleneagles Hotel to Ennismore Group' '1']
#  ['Keith Skeoch to step up as David Nish quits as chief executive of Standard Life'
#   '1']
#  ['$GILD 91 now support. $IBB $BIB https://t.co/GIoOf6zbKv' '1']
#  ['Amazon has been selling surveillance cameras infected with malware $AMZN #Amazon  https://t.co/TohLEQ8FK6 https://t.co/5PR4cBtVVy'
#   '1']
#  ["ITV to pursue takeover of Canada's Entertainment One: Bloomberg" '1']
#  ['$AAPL broke descending channel....will it hold?' '1']
#  ['HSBC appoints business leaders to board' '1']
#  ['Shell offers 50 percent premium to buy BG for $70 billion' '1']
#  ['$MPWR CEO sells 450k april 15th..meh' '1']
#  ["Are ARM Holdings plc, Domino's Pizza Group plc and ASOS plc 3 must-have growth stocks?"
#   '1']
#  ['CompaniesDiageo stays neutral on India boardroom turmoil' '1']
#  ['Tesco share price steady as analysts weigh in on results' '1']
#  ['Berkshire Hathaway names Kara Raiguel to lead General Re unit' '1']
#  ['Tesco sells half of stake in ecommerce site Lazada to Alibaba for Â£90m'
#   '1']
#  ['$AMZN trades in mid to upper range. No break out yet, either direction'
#   '1']
#  ['Sold some $TSLA Puts this morning Closed them at the close. Helps pay for monthly expenses'
#   '1']
#  ["$XLI Potential intermediate top in an Uptrend on a 60'-15'-4' charts http://stks.co/j1TdF"
#   '1']
#  ['Centrica extends gas deals with Gazprom, Statoil' '1']
#  ['Valeant Said to Name New CEO With Pearson Still Hospitalized' '1']
#  ['LSE-Deutsche Boerse merger would signal end to exchange mega-deals'
#   '1']
#  ['$AAPL at pivot area on intraday chart- break here could send this to 50-day SMA, 457.80 http://stks.co/jPbN'
#   '1']
#  ['TalkTalk hires BAE Systems to investigate cyber attack' '1']
#  ['RBS will reportedly appoint Howard Davies as its next chairman' '1']
#  ['UPDATE 1-Meggitt reiterates annual outlook after tough 2014' '1']
#  ['$GILD Sandbagged the guidance so the can use that last 3 billion up.  CC was cautiously optimistic, wait til Next ER for confirmation'
#   '1']
#  ['Entertainment One dispels ITV takeover rumours' '1']
#  ['Ackman, in email, says supports Valeant CEO Pearson' '1']
#  ["Mylan Appoints Ranjan Ray Chaudhuri as Global Commercial Lead for Mylan's Over ..."
#   '1']
#  ['ConAgra Names Former Hillshire Farms CEO Connolly to Top Post' '1']
#  ["Can Christmas Save Sainsbury's plc And Tesco plc?" '1']
#  ["Barclays appoints JPMorgan's Paul Compton as new COO" '1']
#  ['Morrisons finance chief to fill gap as CEO leaves early' '1']
#  ['Shell and BG Shareholders to Vote on Deal at End of January' '1']
#  ['Tesco Abandons Video-Streaming Ambitions in Blinkbox Sale' '1']
#  ['@technik I still have a smaller $GILD pos. Being very tender with cash due to volatility. So reluctant to keep many big positions.'
#   '1']
#  ["Warren Buffett defends Berkshire Hathaway's conglomerate structure"
#   '1']
#  ['Intertek Group announces strategic update outlining its plan' '1']
#  ["CompaniesHome Retail trims gains but is considered 'in play'" '1']
#  ['$CNP Sell Short Position on CNP,...Closed for Profit $ 59,367.00 (7.75%) http://stks.co/ghjc'
#   '1']
#  ['Legal & General share price: Finance chief to step down' '1']
#  ["AB InBev's Latest Bid Said Unlikely to Win SABMiller's Approval" '1']
#  ['Rolls-Royce to Ensure Compliance After Petrobras Bribery Report' '1']
#  ['Is It Worth Investing In Tesco PLC And Prudential plc Now?' '1']
#  ['MillerCoors Board Names Gavin Hattersley Interim CEO' '1']
#  ['NYSE owner ICE may gatecrash Deutsche Boerse-LSE merger' '1']
#  ['CompaniesLSE adds ex-SEC head Schapiro to board' '1']
#  ['$UBNT still having some trouble at the resistance line. Should resolve soon.@cheri1 @strattonite   http://stks.co/c0sU4'
#   '1']
#  ['UPDATE 3-BP settles oil spill-related claims with Halliburton, Transocean'
#   '1']
#  ['Aviva shuts Friends Life head office in rapid integration move' '1']
#  ['Ocwen Reaches Settlement With California Regulator' '1']
#  ['Tesco shareholders back ITV head for chairman' '1']
#  ["New Morrisons duo get former boss's support to diffuse investor tension"
#   '1']]

# %%
# Show numbers till 8 decimal points for debugging.
np.set_printoptions(precision=8)
def get_tweet_mean_topics():
    # Create a matrix where each row corresponds to a label
    mean_thetas = np.zeros((len(['0','1','2']), 10))
    label_arr = ['0','1','2']
    for label in label_arr:
        # call get_tweet_topic_dists
        thetas_t_sparse = get_tweet_topic_dists(train_tweets[new_arr[:,1] ==label], lda_model)
        # convert to a dense vector
        thetas_t = []
        for theta_dist_t_sparse in thetas_t_sparse:
            if not theta_dist_t_sparse:
                continue
            thetas_dist = convert_theta_sparse_to_dense_vector(theta_dist_t_sparse, 10)
            thetas_t.append(thetas_dist)
        # Get the mean theta
        mean_theta_t = np.mean(thetas_t, axis=0)
        mean_thetas[int(label)] = mean_theta_t
        print(mean_thetas[int(label)])
    return mean_thetas
   
mean_arr = get_tweet_mean_topics()

print(mean_arr.shape)
# Out:
# [0.05524788 0.09613806 0.06510896 0.12577334 0.15697701 0.0842003
#  0.079505   0.14383031 0.12629379 0.04681387]
# [0.07387364 0.10512646 0.09042606 0.11614981 0.16387533 0.10442852
#  0.05153171 0.09780794 0.10869371 0.072833  ]
# [0.10686398 0.09435262 0.09911471 0.13842129 0.14652229 0.06953026
#  0.08069048 0.08233255 0.08371951 0.0775198 ]
# (3, 10)

# %%
def plot_tweet_topic_matrix():
    # Get mean tweet topics dists
    mean_thetas = get_tweet_mean_topics()
    # Let's show a heatmap to see which topics occur the most for different labels
    plt.imshow(mean_thetas)
    plt.colorbar()
    plt.show()
plot_tweet_topic_matrix()
# Out:
# [0.05524791 0.09613855 0.06510951 0.12577256 0.15697703 0.08420064
#  0.07950507 0.14382921 0.12629411 0.04681395]
# [0.07387362 0.10512808 0.09042596 0.1161493  0.16387509 0.10442863
#  0.05153174 0.09780881 0.10869196 0.07283298]
# [0.10686421 0.09435198 0.09911517 0.1384222  0.14652204 0.06953062
#  0.08067549 0.08233276 0.08371835 0.07753467]

# %%
# For each topic, let's show the words occuring in that topic, so we can identify it.
for topic_id, topic in lda_model.print_topics(-1):
    print("Topic ID: {} \nAssociated Words:\n {}".format(topic_id, topic ))
    print("\n")
# Out:
# Topic ID: 0
# Associated Words:
#  0.024*"https" + 0.012*"stks" + 0.012*"http" + 0.010*"buy" + 0.010*"long" + 0.009*"trade" + 0.007*"chart" + 0.007*"short" + 0.007*"break" + 0.007*"time"
#
#
# Topic ID: 1
# Associated Words:
#  0.011*"sell" + 0.010*"amzn" + 0.008*"https" + 0.008*"buy" + 0.008*"dip" + 0.008*"ftse" + 0.007*"go" + 0.006*"http" + 0.006*"lead" + 0.006*"price"
#
#
# Topic ID: 2
# Associated Words:
#  0.017*"https" + 0.012*"buy" + 0.007*"say" + 0.007*"offer" + 0.006*"long" + 0.006*"sales" + 0.005*"aapl" + 0.005*"break" + 0.005*"billion" + 0.005*"new"
#
#
# Topic ID: 3
# Associated Words:
#  0.017*"stks" + 0.017*"http" + 0.013*"long" + 0.011*"sabmiller" + 0.009*"sales" + 0.009*"https" + 0.009*"ab" + 0.009*"inbev" + 0.008*"price" + 0.008*"today"
#
#
# Topic ID: 4
# Associated Words:
#  0.029*"http" + 0.028*"stks" + 0.014*"short" + 0.014*"plc" + 0.013*"aapl" + 0.011*"close" + 0.010*"spy" + 0.008*"long" + 0.007*"chart" + 0.006*"https"
#
#
# Topic ID: 5
# Associated Words:
#  0.015*"price" + 0.012*"fall" + 0.010*"update" + 0.009*"share" + 0.009*"gain" + 0.008*"sales" + 0.008*"dividend" + 0.008*"year" + 0.006*"hit" + 0.006*"target"
#
#
# Topic ID: 6
# Associated Words:
#  0.016*"http" + 0.016*"stks" + 0.015*"share" + 0.012*"astrazeneca" + 0.012*"drug" + 0.009*"price" + 0.008*"aapl" + 0.008*"like" + 0.008*"come" + 0.006*"market"
#
#
# Topic ID: 7
# Associated Words:
#  0.025*"https" + 0.022*"recall" + 0.021*"tsla" + 0.016*"model" + 0.014*"tesla" + 0.008*"deal" + 0.007*"stks" + 0.007*"http" + 0.007*"billion" + 0.007*"seat"
#
#
# Topic ID: 8
# Associated Words:
#  0.014*"new" + 0.014*"look" + 0.011*"sell" + 0.009*"tesco" + 0.008*"get" + 0.007*"tsla" + 0.006*"spy" + 0.006*"sales" + 0.006*"continue" + 0.006*"bounce"
#
#
# Topic ID: 9
# Associated Words:
#  0.008*"long" + 0.008*"price" + 0.007*"aapl" + 0.007*"share" + 0.006*"short" + 0.006*"approve" + 0.006*"group" + 0.006*"billion" + 0.006*"high" + 0.006*"takeover"
