# %%
# %load_ext autoreload
# %autoreload 2
from datasets import load_dataset
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay
import numpy as np
from scipy.sparse import hstack
import nltk as nltk
from nltk import word_tokenize          
from nltk.stem import WordNetLemmatizer 
from sklearn.feature_extraction.text import CountVectorizer
nltk.download('punkt')
nltk.download('wordnet')
nltk.download('vader_lexicon')
from nltk.sentiment.vader import SentimentIntensityAnalyzer
import matplotlib.pyplot as plt
import numpy as np
from gensim.utils import simple_preprocess
from gensim.parsing.preprocessing import STOPWORDS
from IPython.display import clear_output
import matplotlib.pyplot as plt
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\adnan\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\adnan\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\adnan\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %%
# Loading files
train_files = [
    'data/FiQA_ABSA_task1/task1_headline_ABSA_train.json',
    'data/FiQA_ABSA_task1/task1_post_ABSA_train.json'
]

# %%
## Loading data from JSON
import json

def load_fiqa_sa_from_json(json_files):
    train_text = []
    train_labels = []

    for file in json_files:
        with open(file, 'r', encoding='UTF-8') as handle:
            dataf = json.load(handle)
        dataf_text = [dataf[k]["sentence"] for k in dataf.keys()]
        train_text.extend(dataf_text)
        dataf_labels = [float(dataf[k]["info"][0]["sentiment_score"]) for k in dataf.keys()]
        train_labels.extend(dataf_labels)
    train_text = np.array(train_text)
    train_labels = np.array(train_labels)
    return train_text, train_labels


def threshold_scores(scores):
    """
    Convert sentiment scores to discrete labels.
    0 = negative.
    1 = neutral.
    2 = positive.
    """
    labels = []
    for score in scores:
        if score < -0.2:
            labels.append(0)
        elif score > 0.2:
            labels.append(2)
        else:
            labels.append(1)
            
    return np.array(labels)


all_text, all_labels = load_fiqa_sa_from_json(train_files)
    
print(f'Number of instances: {len(all_text)}')
print(f'Number of labels: {len(all_labels)}')

all_labels = threshold_scores(all_labels)
print(f'Number of negative labels: {np.sum(all_labels==0)}')
print(f'Number of neutral labels: {np.sum(all_labels==1)}')
print(f'Number of positive labels: {np.sum(all_labels==2)}')
# Out:
# Number of instances: 1111
# Number of labels: 1111
# Number of negative labels: 310
# Number of neutral labels: 195
# Number of positive labels: 606

# %%
# Split the data into training, validation, testing sets.

from sklearn.model_selection import train_test_split

# Split test data from training data
train_documents, test_documents, train_labels, test_labels = train_test_split(
    all_text, 
    all_labels, 
    test_size=0.2, 
    stratify=all_labels  # make sure the same proportion of labels is in the test set and training set
)

# Split validation data from training data
train_documents, val_documents, train_labels, val_labels = train_test_split(
    train_documents, 
    train_labels, 
    test_size=0.2, 
    stratify=train_labels  # make sure the same proportion of labels is in the test set and training set
)

print(f'Number of training instances = {len(train_documents)}')
print(f'Number of validation instances = {len(val_documents)}')
print(f'Number of test instances = {len(test_documents)}')
# Out:
# Number of training instances = 710
# Number of validation instances = 178
# Number of test instances = 223

# %%
# Print example tweet
print(f'What does one instance look like from the training set? \n\n{train_documents[234]}')
print(f'...and here is its corresponding label \n\n{train_labels[234]}')
# Out:
# What does one instance look like from the training set?
#
# Rolls-Royce to Ensure Compliance After Petrobras Bribery Report
# ...and here is its corresponding label
#
# 1

# %% [markdown]
# # 1. Preprocessing using  lemmatization
# We create a lemmatizer tokenizer that reduces words to their root forms. This reduces the vocabulary size.

# %%
# We create a lemmaTokenizer class that applies lemmatization when tokenizing.
class LemmaTokenizer(object):
    
    def __init__(self):
        self.wnl = WordNetLemmatizer()
        
    def __call__(self, tweets):
        return [self.wnl.lemmatize(self.wnl.lemmatize(self.wnl.lemmatize(tok, pos='n'), pos='v'), pos='a') for tok in word_tokenize(tweets)]

# %% [markdown]
# # 2.1 Using bi-grams + unigrams as feature
# We apply our tokenizer and set it to allow ngram features (both unigrams and bigrams).

# %%
vectorizer = CountVectorizer(tokenizer=LemmaTokenizer(), ngram_range=(1,2))
vectorizer.fit(train_documents)
X_train = vectorizer.transform(train_documents)
X_val = vectorizer.transform(val_documents)
X_test_documents = vectorizer.transform(test_documents)
# Let's look at some of the features.
print(list(vectorizer.vocabulary_)[:10])
# Out:
# C:\Users\adnan\anaconda3\envs\data_analytics\lib\site-packages\sklearn\feature_extraction\text.py:516: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   warnings.warn(
# ['$', 'mo', 'look', 'good', 'here', 'at', '58.65', '.', 'call', 'be']

# %%
# Checking full vocabulary size:
print(f' Full vocabulary size: {len(vectorizer.vocabulary_)}')
vocabulary = vectorizer.vocabulary_
# Out:
#  Full vocabulary size: 10477

# %%
# Now let's fit our data to the model.
classifier = LogisticRegression()
classifier.fit(X_train, train_labels)
y_val_pred = classifier.predict(X_val)
cm = confusion_matrix(val_labels, y_val_pred)
cm_display = ConfusionMatrixDisplay(cm).plot()
print(classification_report(val_labels, y_val_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.65      0.48      0.55        50
#            1       0.40      0.06      0.11        31
#            2       0.65      0.91      0.76        97
#
#     accuracy                           0.64       178
#    macro avg       0.57      0.48      0.47       178
# weighted avg       0.60      0.64      0.59       178

# %%
# Using POS-NEG lexicon features

# %%
# instantiate analyzer
analyser = SentimentIntensityAnalyzer()
# fetch vocabulary
vocabulary = vectorizer.vocabulary_
# create empy holders for lexicon scores.
lexicon_pos_scores = np.zeros((1, len(vocabulary)))
lexicon_neg_scores = np.zeros((1, len(vocabulary)))

for i, term in enumerate(vocabulary):
    if term in analyser.lexicon and analyser.lexicon[term] > 0:
        lexicon_pos_scores[0, i] = 1
    elif term in analyser.lexicon and analyser.lexicon[term] < 0:
        lexicon_neg_scores[0, i] = 1

# %%
# This enables us to get the total positive and total negative counts for each set:
lexicon_pos_train = np.sum(X_train.multiply(lexicon_pos_scores), axis=1)
lexicon_pos_val = np.sum(X_val.multiply(lexicon_pos_scores), axis=1)
lexicon_pos_test = np.sum(X_test_documents.multiply(lexicon_pos_scores), axis=1)

lexicon_neg_train = np.sum(X_train.multiply(lexicon_neg_scores), axis=1)
lexicon_neg_val = np.sum(X_val.multiply(lexicon_neg_scores), axis=1)
lexicon_neg_test = np.sum(X_test_documents.multiply(lexicon_neg_scores), axis=1)

# %%
X_train = hstack((X_train, lexicon_pos_train, lexicon_neg_train))
X_val = hstack((X_val, lexicon_pos_val, lexicon_neg_val))
X_test_documents = hstack((X_test_documents, lexicon_pos_test, lexicon_neg_test))

# %%
classifier = LogisticRegression()
classifier.fit(X_train, train_labels)
y_val_pred = classifier.predict(X_val)
# Checking performance
cm = confusion_matrix(val_labels, y_val_pred)
cm_display = ConfusionMatrixDisplay(cm).plot()
print(classification_report(val_labels, y_val_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.62      0.50      0.56        50
#            1       0.50      0.03      0.06        31
#            2       0.64      0.90      0.75        97
#
#     accuracy                           0.63       178
#    macro avg       0.59      0.48      0.45       178
# weighted avg       0.61      0.63      0.57       178

# %%
# Key part is investigating the errors by looking at the actual values, so let's do that:
error_indexes = y_val_pred != val_labels  # let's compare predictions to true values for labels

# get the tweets where the classifier made an error:
tweets_err = np.array(val_documents)[error_indexes]

pred_err = y_val_pred[error_indexes]
true_err = np.array(val_labels)[error_indexes]

for i in range(10):
    print(f'Tweet: {tweets_err[i]}; true label = {true_err[i]}, prediction = {pred_err[i]}.')
# Out:
# Tweet: $GOOGL Hit With Lawsuit from Russian Search Engine $YNDX http://stks.co/b1kD8; true label = 1, prediction = 2.
# Tweet: Shell's $70 Billion BG Deal Meets Shareholder Skepticism; true label = 0, prediction = 2.
# Tweet: Centrica extends gas deals with Gazprom, Statoil; true label = 1, prediction = 2.
# Tweet: RT @ACInvestorBlog $AAPL still on track for $500; true label = 1, prediction = 2.
# Tweet: End Of Day Scan: Stochastic Overbought $JDST $FREE $BLRX $LPG $AFSI $DVAX $HDGE $AHT $ALR $ASMB  www.dailystockplays.com; true label = 0, prediction = 2.
# Tweet: $FB Big Money Is Pouring Into Facebook From All Directions;http://stks.co/sOwG; true label = 2, prediction = 0.
# Tweet: Germanwings disaster will not affect image of budget air travel - easyJet; true label = 1, prediction = 2.
# Tweet: $GRPN might be selling off ahead of $P earnings...; true label = 0, prediction = 2.
# Tweet: AstraZeneca's patent on asthma drug invalidated by US court; true label = 0, prediction = 2.
# Tweet: Mylan Appoints Ranjan Ray Chaudhuri as Global Commercial Lead for Mylan's Over ...; true label = 1, prediction = 0.

# %% [markdown]
# # Performance on test set

# %%
# Let's test the performance on the test set.
y_test_pred = classifier.predict(X_test_documents)
# Checking performance
cm = confusion_matrix(test_labels, y_test_pred)
cm_display = ConfusionMatrixDisplay(cm).plot()
print(classification_report(test_labels, y_test_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.65      0.45      0.53        62
#            1       0.73      0.21      0.32        39
#            2       0.66      0.92      0.77       122
#
#     accuracy                           0.66       223
#    macro avg       0.68      0.52      0.54       223
# weighted avg       0.67      0.66      0.63       223

# %% [markdown]
# # 4. Extracting topics using LDA

# %%
# First let's get another clean split of the data. 
from sklearn.model_selection import train_test_split

# Split test data from training data
train_documents, test_documents, train_labels, test_labels = train_test_split(
    all_text, 
    all_labels, 
    test_size=0.2, 
    stratify=all_labels  # make sure the same proportion of labels is in the test set and training set
)

# Split validation data from training data
train_documents, val_documents, train_labels, val_labels = train_test_split(
    train_documents, 
    train_labels, 
    test_size=0.2, 
    stratify=train_labels  # make sure the same proportion of labels is in the test set and training set
)

print(f'Number of training instances = {len(train_documents)}')
print(f'Number of validation instances = {len(val_documents)}')
print(f'Number of test instances = {len(test_documents)}')
# Out:
# Number of training instances = 710
# Number of validation instances = 178
# Number of test instances = 223

# %%
 # We use the function below for tokenization. Does a number of things, including removing small words, deleting words with special chars,  changing uppercase to lowercase, and more.
def preprocess(text):
    final_results=[]
    for token in simple_preprocess(text) : 
        if token not in STOPWORDS:
            final_results.append(WordNetLemmatizer().lemmatize(token, 'v'))
    return final_results

# Create a list of preprocessed documents
processed = []
for doc in train_documents:
    processed.append(preprocess(doc))
print(processed)
# Out:
# [['break', 'tesla', 'recall', 'model', 'cars', 'detail', 'tsla'], ['today', 'close', 'long', 'tsla', 'amtd', 'twtr', 'fb', 'aapl', 'celg', 'longer', 'term', 'technical', 'swing', 'long', 'basis'], ['tsla', 'announce', 'recall', 'stock', 'sell', 'stock', 'teflon', 'win', 'forever'], ['sainsbury', 'say', 'outperform', 'rival', 'tough', 'market'], ['break', 'week', 'highs', 'time', 'look', 'great', 'ahs', 'baby', 'post', 'ige', 'irdm', 'ewbc', 'phys', 'ulta', 'vnet', 'biv', 'https', 'jzuzmu'], ['gale', 'breakout', 'come', 'soon'], ['goodwin', 'face', 'scottish', 'prosecution', 'rbs'], ['apple', 'expect', 'launch', 'new', 'iphone', 'ipad', 'today', 'aapl', 'https', 'xfnicwebeg'], ['royal', 'mail', 'turnaround', 'prove', 'expensive', 'tough', 'uk', 'market'], ['potential', 'bearish', 'shark', 'pattern', 'point', 'take', 'http', 'stks', 'ggh'], ['tsla', 'recall', 'model', 'suvs', 'seat', 'belt', 'fix'], ['gsk', 'novartis', 'complete', 'deal', 'reshape', 'drugmakers'], ['rt', 'acinvestorblog', 'aapl', 'track'], ['aapl', 'break', 'descend', 'channel', 'hold'], ['arm', 'profit', 'sales', 'shift', 'away', 'mobile', 'gain', 'pace'], ['bbry', 'let', 'today'], ['xlb', 'weakest', 'sector', 'year', 'possible', 'false', 'breakout', 'http', 'stks', 'dl'], ['cgrantwsj', 'think', 'tsla', 'bubble', 'time', 'long', 'ppl', 'love', 'cars', 'get', 'fund'], ['sds', 'pick', 'speed', 'call', 'http', 'stks', 'eik', 'week', 'call', 'http', 'stks', 'eil'], ['nyse', 'owner', 'ice', 'consider', 'offer', 'lse'], ['astrazeneca', 'sell', 'drug', 'right', 'perrigo', 'mln'], ['notable', 'gainers', 'liquid', 'option', 'name', 'morning', 'include', 'stx', 'nem', 'wdc', 'gme'], ['citrix', 'systems', 'ctxs', 'position', 'increase', 'mizuho', 'https', 'lkq', 'flp', 'sharestocknews'], ['unilever', 'profit', 'rise', 'despite', 'sales', 'slump', 'china'], ['bad', 'idea', 'min', 'predictions', 'base', 'faith', 'rt', 'dandyduct', 'aapl', 'sell', 'signal', 'hit', 'min'], ['tsla', 'wish', 'put', 'support', 'pop', 'https', 'hfklq', 'wobv'], ['dig', 'weekly', 'stochastics', 'finally', 'start', 'turn', 'long', 'consolidation', 'buy'], ['berkshire', 'apply', 'boost', 'well', 'fargo', 'stake', 'percent'], ['tsla', 'lot', 'green', 'min', 'watch', 'hourly', 'possible', 'resistance', 'currently'], ['end', 'day', 'scan', 'bullish', 'ma', 'crossovers', 'bbva', 'pds', 'ntls', 'ngl', 'sbrcy', 'fgl', 'mtnoy', 'ttt', 'www', 'dailystockplays', 'com'], ['skh', 'http', 'stks', 'long', 'setup', 'watch', 'continuation', 'volume', 'expansion', 'hot', 'sector'], ['tesco', 'share', 'price', 'grocer', 'face', 'sfo', 'investigation', 'outcome'], ['germanwings', 'disaster', 'affect', 'image', 'budget', 'air', 'travel', 'easyjet'], ['cnp', 'sell', 'short', 'position', 'cnp', 'close', 'profit', 'http', 'stks', 'ghjc'], ['update', 'easyjet', 'passenger', 'number', 'aer', 'lingus', 'traffic', 'february'], ['like', 'price', 'action', 'swks', 'currently', 'target', 'year', 'end'], ['isrg', 'pt', 'raise', 'leerink', 'keep', 'outperform', 'rat'], ['yoku', 'high', 'volume', 'blast', 'friday', 'go', 'higher', 'http', 'stks', 'qsal'], ['zurich', 'insurance', 'consider', 'offer', 'uk', 'rival', 'rsa', 'insurance'], ['tullow', 'oil', 'suspend', 'dividend', 'amid', 'oil', 'price', 'fall'], ['goldman', 'sachs', 'barclays', 'hsbc', 'downplay', 'brexit', 'threat'], ['britain', 'ftse', 'gain', 'land', 'securities', 'dividend', 'hike'], ['astrazeneca', 'daiichi', 'sankyo', 'jointly', 'commercialise', 'movantik'], ['multi', 'mcd', 'chart', 'finally', 'lead', 'fall', 'price', 'stability', 'question', 'stock', 'come', 'weeks', 'tell'], ['tesco', 'lead', 'leap', 'ftse', 'mark', 'spencer', 'drop'], ['city', 'spirit', 'sink', 'diageo', 'come', 'short', 'sales', 'slide'], ['fusioniq', 'new', 'positive', 'time', 'signal', 'sbux', 'today', 'https', 'imlxz', 'yna', 'retweet', 'signal'], ['tsla', 'days', 'row', 'neeeeds'], ['je', 'look', 'like', 'bounce', 'nice', 'finish', 'today', 'hammer', 'nice', 'volume', 'finger', 'cross'], ...

# %%
from gensim.corpora import Dictionary
# create a dictionary of word<->id key/val pairs.
dictionary = Dictionary(processed) 
print(dictionary)

bow_corpus = [dictionary.doc2bow(doc) for doc in processed]
# Out:
# Dictionary(2325 unique tokens: ['break', 'cars', 'detail', 'model', 'recall']...)

# %%
# Getting means of thetas

from gensim.matutils import any2sparse
from gensim.models import LdaModel

lda_model =  LdaModel(bow_corpus, 
                      num_topics=10, 
                      id2word=dictionary,                                    
                      passes=10,
                    ) 

def get_tweet_topic_dists(train_documents, lda_model):
    thetas = []
    for i in range(len(train_documents)):
        # Get the tweet
        unseen_tweet = train_documents[i]

        # Preprocess for bag of words:
        bow_vector = dictionary.doc2bow(preprocess(unseen_tweet))

        # Let's get the topic distribution:
        theta_tweet = lda_model[bow_vector]

        thetas.append(theta_tweet)

    return thetas

thetas = get_tweet_topic_dists(train_documents, lda_model)

# %%
# We will use colours to represent topics.
colours = ['blue', 'green', 'red', 'yellow', 'black', 'pink', 'purple',
           'orange',  'darkgreen',  'navy', 'crimson']

def convert_theta_sparse_to_dense_vector(theta_dist_sparse, num_topics):
    theta_dist = np.zeros(num_topics)  # an empty array
    
    # get active topics
    active_topics_for_dist, probs = map(list, zip(*theta_dist_sparse))
    
    # add to thetas_dist
    for i, topic in enumerate(active_topics_for_dist):
        if topic >= num_topics:
            break
            
        theta_dist[topic] = probs[i]
    
    return theta_dist

# Create barchart
def plot_theta(thetas, i, num_tweets, num_topics):
    plt.subplot(int((num_tweets+1)/2), 2, i+1)
    theta_dist = convert_theta_sparse_to_dense_vector(thetas[i], num_topics)
    plt.bar(x=np.arange(len(theta_dist)), height=theta_dist, color=colours, tick_label=np.arange(num_topics))

plt.figure(figsize=(20,15))

num_tweets = 10
num_topics = 10
counter = 0
for i, theta in enumerate(thetas):
    if (counter < 10):
        plot_theta(thetas, i, num_tweets, num_topics)
        counter +=1
plt.show()

# %%
# Merge arrays for later 
arr = train_documents
arr_2 = train_labels

arrays = [arr,arr_2]
new_arr = np.stack(arrays, axis=1)
print(new_arr[new_arr[:,1] =='1'])
# Out:
# [['Goodwin not to face Scottish prosecution over RBS' '1']
#  ['Royal Mail turnaround proving expensive in tough UK market' '1']
#  ['RT @ACInvestorBlog $AAPL still on track for $500' '1']
#  ['$AAPL broke descending channel....will it hold?' '1']
#  ['Germanwings disaster will not affect image of budget air travel - easyJet'
#   '1']
#  ['$CNP Sell Short Position on CNP,...Closed for Profit $ 59,367.00 (7.75%) http://stks.co/ghjc'
#   '1']
#  ['Goldman Sachs, Barclays, HSBC downplay Brexit threat' '1']
#  ['$MA http://stks.co/1CYN continues to consolidate / base here' '1']
#  ['$UBNT still having some trouble at the resistance line. Should resolve soon.@cheri1 @strattonite   http://stks.co/c0sU4'
#   '1']
#  ['Looks like its booking a one way ticket to its 40 week MA near 50. Losing 10 week here $LULU http://chart.ly/7xb9h9b'
#   '1']
#  ["Credit Suisse poaches Prudential's Thiam for Asian push" '1']
#  ['$GILD Sandbagged the guidance so the can use that last 3 billion up.  CC was cautiously optimistic, wait til Next ER for confirmation'
#   '1']
#  ['FDA panel backs safety updates for AstraZeneca, Takeda drugs' '1']
#  ['Philip Morris, BAT Sue Over Law Taking Branding Off Packs' '1']
#  ["Spain's Caixabank launches new takeover bid for Banco BPI" '1']
#  ['AB InBev attacks SABMiller bid rebuffal' '1']
#  ["RBS Pays $1.7 Billion to Scrap U.K. Treasury's Dividend Rights" '1']
#  ['CompaniesLSE adds ex-SEC head Schapiro to board' '1']
#  ["AB InBev to Sell SABMiller Stake in China's Snow Beer" '1']
#  ['Tesco share price steady as analysts weigh in on results' '1']
#  ['UPDATE 3-Stifel to buy former Lehman brokerage from Barclays' '1']
#  ['CompaniesDixons Carphone to close 134 UK stores as sales jump' '1']
#  ['$PRGN A bottom right here?' '1']
#  ['easyJet expects resilient demand to withstand security fears' '1']
#  ['Apple: Another attempt to break out on Apple but with weak PVT   $AAPL #Trading #investing #aapl https://t.co/DNh7Hgv22V'
#   '1']
#  ['AB InBev offers SABMiller $3 billion breakup fee' '1']
#  ['Shire share price under pressure after $32bn Baxalta deal' '1']
#  ['$COST Costco less than stellar day but it held the 50 day moving average'
#   '1']
#  ["AB InBev's Latest Bid Said Unlikely to Win SABMiller's Approval" '1']
#  ["$HAL If bulls lucky enuff to get an upside gap fill, better take it. Wouldn't chase it here. http://stks.co/r12Us"
#   '1']
#  ['Standard Chartered Not Raising Capital Yet As Dividend Cut' '1']
#  ['Irish housebuilder Cairn Homes plans London listing' '1']
#  ["Despite sales growth, UK's Tesco cautions recovery to be bumpy" '1']
#  ['$RAD All my charts are flashing oversold.' '1']
#  ['Shell challenges Exxon dominance with 47 billion-pound bid for BG' '1']
#  ['METALS-Zinc surges 12 pct after Glencore cuts output, fuelling metals rally'
#   '1']
#  ['HSBC appoints business leaders to board' '1']
#  ['$aapl short term fund/redemption liquidations.. Should have the channel cleared soon and on solid footing. $520 is new floor come July! :)'
#   '1']
#  ['Intertek Group announces strategic update outlining its plan' '1']
#  ['MillerCoors Board Names Gavin Hattersley Interim CEO' '1']
#  ['$AAPL at pivot area on intraday chart- break here could send this to 50-day SMA, 457.80 http://stks.co/jPbN'
#   '1']
#  ['NYSE owner ICE may gatecrash Deutsche Boerse-LSE merger' '1']
#  ['MarketsBP promotes upstream boss to deputy CEO' '1']
#  ['Shire CEO steps up drive to get Baxalta board talking' '1']
#  ['CompaniesNew Aggreko CEO to reshape business, strip costs' '1']
#  ['PRESS: Serco Set To Appoint Roy Gardner, Ex-Centrica, As Chairman - FT'
#   '1']
#  ['EA Launches Origin Online Game Distribution for Mac http://stks.co/aKTU via MacRumors $EA'
#   '1']
#  ['U.S. Debt Lures Schroders as ECB Depresses Rates' '1']
#  ['AB InBev to sell more SAB assets as seeks EU deal approval' '1']
#  ['$NVDA sideways' '1']
#  ['CompaniesHoward Davies appointment as RBS director delayed' '1']
#  ["SAB's Chairman Digs In With Board Divided on InBev Offer" '1']
#  ['Shell offers 50 percent premium to buy BG for $70 billion' '1']
#  ['CEOs of BPM, UBI meet Italy econ minister as M&A talk heats up' '1']
#  ['Key level to watch in $FB for today is 25.53-- watching to see if it can hold as support http://stks.co/bOH4'
#   '1']
#  ['UPDATE 1-Meggitt reiterates annual outlook after tough 2014' '1']
#  ['Shell and BG Shareholders to Vote on Deal at End of January' '1']
#  ['$GLD http://stks.co/44ow On closer inspection.  Resistance 10 points north at 200d and downward trendline. Chart 2 of 2.'
#   '1']
#  ['HSBC shakes up board with two new business chiefs, three departures'
#   '1']
#  ["My $DWA play up 6% today. I'm still skeptical. Will take profits. Not a time cheer"
#   '1']
#  ['$AAPL Action into the close indicates that $AAPL probably hit a near term high.  Momentum slowing after a huge run.'
#   '1']
#  ['UPDATE: Barclays Expects Gain After Settling With Lehman Bros Trustee'
#   '1']
#  ['RT @tomhend777 $MU needs to hold here -Broken for now. Needs big flush. Still not technically oversold so now big bounce yet'
#   '1']
#  ["ITV to pursue takeover of Canada's Entertainment One: Bloomberg" '1']
#  ['UPDATE 1-BP shareholders back more disclosure on climate change risks'
#   '1']
#  ['Petrofac share price rises despite Â£30m costs on North Sea project'
#   '1']
#  ['After Barclays and Bank of America, Citigroup has blockchain in sight'
#   '1']
#  ['UPDATE 1-Dairy Crest loses a third of Morrisons milk contract' '1']
#  ["Mylan Appoints Ranjan Ray Chaudhuri as Global Commercial Lead for Mylan's Over ..."
#   '1']
#  ['GlaxoSmithKline starts hunt for successor to CEO Witty' '1']
#  ['Horizonte acquires neighbouring Glencore nickel property in Brazil'
#   '1']
#  ['$PLUG Closed short position. Small gain. Not interested in options expiring worthless'
#   '1']
#  ["CompaniesAB InBev signals it won't go hostile for SABMiller" '1']
#  ['ConAgra Names Former Hillshire Farms CEO Connolly to Top Post' '1']
#  ['$ACAD under $2 today?' '1']
#  ["$AAPL Now I'm glad I got stopped out of my $113 weeklies when I did. Will re-enter next Monday for the #earnings run-up."
#   '1']
#  ['Market Report: Eight-day rally ends for FTSE 100 and Standard Chartered'
#   '1']
#  ["Insurer Old Mutual picks Standard Bank's Hemphill as new CEO" '1']
#  ["$RUSS Don't catch falling knives, but I think an entry is coming soon on this"
#   '1']
#  ['Legal & General share price: Finance chief to step down' '1']
#  ['$AAPL AAPL finally breaking under the 49 M.A.. With no buybacks this week, look for AAPL to test the 120 support area.'
#   '1']
#  ['Ackman, in email, says supports Valeant CEO Pearson' '1']
#  ['$MPWR CEO sells 450k april 15th..meh' '1']
#  ["$aapl key is to breakout above 460 on solid volume or else it's a no trade for now"
#   '1']
#  ['Morrisons faces festive sales test' '1']
#  ['Should You Follow Berkshire Hathaway Into Apple Stock?' '1']
#  ['$AMZN Trailing 12 months operating cash flow rose 48% to $4.98 billion & free cash flow decreased 63% to $388 million http://stks.co/c06zG'
#   '1']
#  ['4 beaten-down Internet companies that may be ripe for a #takeover target: #Twitter $TWTR - #LinkedIn $LNKD - #Yahoo! $YHOO - #Groupon $GRPN'
#   '1']
#  ['$AAPL bounce right now has no vol, more vol when it slid' '1']
#  ['$SLW is down, but weekly $34 calls (-28.95%), .23 x .25 have 321 volume. Worth a chance here, jmho: http://stks.co/1Qfg'
#   '1']
#  ["$GLD http://stks.co/jr8 Daily chart - though RSI and Stoch. point at a possible move up, there's a lot of resistance."
#   '1']
#  ['Tesco Abandons Video-Streaming Ambitions in Blinkbox Sale' '1']
#  ['Barclays poaches new chief operating officer Paul Compton from JP Morgan Chase'
#   '1']
#  ['Should You Buy Jumbo Yielders British American Tobacco plc, Centrica PLC & John Wood Group PLC?'
#   '1']
#  ['$AAPL Taking out the shorts here, a punishing reminder not to spear the  strongest in the herd.'
#   '1']
#  ['Berkshire Hathaway names Kara Raiguel to lead General Re unit' '1']
#  ["Tesco closes in on new chairman with Dixons Carphone's John Allan in the frame"
#   '1']
#  ['Royal Mail gets mixed bag from Ofcom postal regulation report' '1']
#  ['RT @StockTwits RT @fallondpicks Breadth Consolidates: After weeks of steady gains,advances in mkt breadth slowe... http://stks.co/2TrG $QQQ'
#   '1']
#  ["$ENDP Was looking for a long entry but today's price action wasn't appealing"
#   '1']
#  ['Entertainment One dispels ITV takeover rumours' '1']
#  ['$FAST $GWW - daily sales slowing again, pretty timely coincident indicator https://t.co/m6BKHBkzK5'
#   '1']
#  ['Rio Tinto CEO says iron ore market at equilibrium' '1']
#  ['$YHOO fishy action. New party interested (DailyMail) bounce & retreats. Not short by any means, but action questions big up move. Thoughts?'
#   '1']
#  ['$mako hanging in well today. still in a basing pattern. have eyes on it'
#   '1']
#  ['$vxx starting to creep up while $spy sits near hod ...' '1']
#  ['Aviva shuts Friends Life head office in rapid integration move' '1']
#  ['$UUP at major resistance right now. Can go much higher if it can break above. May take several attempts - few days to a week'
#   '1']
#  ["Warren Buffett defends Berkshire Hathaway's conglomerate structure"
#   '1']
#  ['RT @andrewnyquist Chartology: Yahoo: http://stks.co/1itr $YHOO  Crazy looking chart, but nearing breakout resistance line...'
#   '1']
#  ["$WGO's BoD was right to reject the offer. That company is low because of the economy, not because of any type of mismanagement or anything."
#   '1']
#  ['Johnson Matthey profit falls but dividend rises' '1']
#  ['RBS will reportedly appoint Howard Davies as its next chairman' '1']
#  ['$TRIP maintains Neutral rating at JP Morgan- PT cut $61 from $66' '1']
#  ['Whats up with $LULU?  Numbers looked good, not great, but good.  I think conference call will instill confidence.'
#   '1']
#  ['CompaniesDiageo stays neutral on India boardroom turmoil' '1']
#  ['$BABA may take a few days wks months watch what happened to $FB $TWTR after they IPO. mrkt needs to washout. to hunt well need 2 wait stalk.'
#   '1']
#  ["Are ARM Holdings plc, Domino's Pizza Group plc and ASOS plc 3 must-have growth stocks?"
#   '1']
#  ['$PG Ackman making the big added efficiency argument. betting on operational imporvement in a huge conglomerate can go either way imo.'
#   '1']
#  ['Analyst Views: Astrazeneca shares have seen recent volatility; what will 2015 ...'
#   '1']
#  ['$GOOGL Hit With Lawsuit from Russian Search Engine $YNDX http://stks.co/b1kD8'
#   '1']
#  ['UPDATE 1-SABMiller 2nd-quarter underlying sales rise, forex impacts margins'
#   '1']
#  ['Adobe Receives New Rating from Top Analyst $ADBE https://t.co/LJNXPEvHZN'
#   '1']
#  ["Should you buy Associated British Foods plc, Great Portland Estates plc and Dunelm Group plc following today's news?"
#   '1']
#  ["Merged LSE and Deutsche BÃ¶rse would be led by Germany's Kengeter" '1']]

# %%
# Show numbers till 8 decimal points for testing.
np.set_printoptions(precision=8)
def get_tweet_mean_topics():
    # Create a matrix where each row corresponds to a label, and each column to a topic.
    mean_thetas = np.zeros((len(['0','1','2']), 10))
    label_arr = ['0','1','2']
    for label in label_arr:
        # call get_tweet_topic_dists
        thetas_t_sparse = get_tweet_topic_dists(train_documents[new_arr[:,1] ==label], lda_model)
        # convert to a dense vector
        thetas_t = []
        for theta_dist_t_sparse in thetas_t_sparse:
            if not theta_dist_t_sparse:
                continue
            thetas_dist = convert_theta_sparse_to_dense(theta_dist_t_sparse, 10)
            thetas_t.append(thetas_dist)
        # Get the mean theta
        mean_theta_t = np.mean(thetas_t, axis=0)
        mean_thetas[int(label)] = mean_theta_t
        print(mean_thetas[int(label)])
    return mean_thetas
   
mean_arr = get_tweet_mean_topics()

print(mean_arr.shape)
# Out:
# [0.12949761 0.10103948 0.08919574 0.1185434  0.06885499 0.08563887
#  0.10244957 0.09539098 0.10018735 0.09164317]
# [0.10215979 0.08021216 0.15392726 0.07865216 0.06795647 0.12488192
#  0.08714188 0.14946481 0.05267207 0.08381116]
# [0.09711859 0.1101151  0.0761425  0.07666854 0.08552735 0.08008524
#  0.09038189 0.14325275 0.10804544 0.1113056 ]
# (3, 10)

# %%
def plot_tweet_topic_matrix():
    # Get mean tweet topics dists
    mean_thetas = get_tweet_mean_topics()
    # Let's show a heatmap to see which topics occur the most for different labels
    plt.imshow(mean_thetas)
    plt.colorbar()
    plt.show()
plot_tweet_topic_matrix()
# Out:
# [0.12949873 0.10104147 0.08919435 0.11854267 0.06885485 0.08563914
#  0.10244944 0.09539074 0.10018744 0.09164236]
# [0.10215982 0.08021228 0.15392707 0.07865177 0.06795644 0.12488144
#  0.08714188 0.14946552 0.0526718  0.08381165]
# [0.09711861 0.11011627 0.07610203 0.07666792 0.08552767 0.08008518
#  0.09038164 0.14325221 0.10808598 0.11130549]
