# %%
# %load_ext autoreload
# %autoreload 2
from datasets import load_dataset
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay
import numpy as np
from scipy.sparse import hstack
import nltk as nltk
from nltk import word_tokenize          
from nltk.stem import WordNetLemmatizer 
from sklearn.feature_extraction.text import CountVectorizer
nltk.download('punkt')
nltk.download('wordnet')
nltk.download('vader_lexicon')
from nltk.sentiment.vader import SentimentIntensityAnalyzer
import matplotlib.pyplot as plt
import numpy as np
from gensim.utils import simple_preprocess
from gensim.parsing.preprocessing import STOPWORDS
from IPython.display import clear_output
import matplotlib.pyplot as plt
from gensim.matutils import any2sparse
from gensim.models import LdaModel
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\adnan\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\adnan\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\adnan\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %%
# Loading files
train_files = [
    'data/FiQA_ABSA_task1/task1_headline_ABSA_train.json',
    'data/FiQA_ABSA_task1/task1_post_ABSA_train.json'
]

# %%
## Loading data from JSON
import json

def load_fiqa_sa_from_json(json_files):
    train_text = []
    train_labels = []

    for file in json_files:
        with open(file, 'r', encoding='UTF-8') as handle:
            dataf = json.load(handle)
        dataf_text = [dataf[k]["sentence"] for k in dataf.keys()]
        train_text.extend(dataf_text)
        dataf_labels = [float(dataf[k]["info"][0]["sentiment_score"]) for k in dataf.keys()]
        train_labels.extend(dataf_labels)
    train_text = np.array(train_text)
    train_labels = np.array(train_labels)
    return train_text, train_labels


def threshold_scores(scores):
    """
    Convert sentiment scores to discrete labels.
    0 = negative.
    1 = neutral.
    2 = positive.
    """
    labels = []
    for score in scores:
        if score < -0.2:
            labels.append(0)
        elif score > 0.2:
            labels.append(2)
        else:
            labels.append(1)
            
    return np.array(labels)


all_text, all_labels = load_fiqa_sa_from_json(train_files)
    
print(f'Number of instances: {len(all_text)}')
print(f'Number of labels: {len(all_labels)}')

all_labels = threshold_scores(all_labels)
print(f'Number of negative labels: {np.sum(all_labels==0)}')
print(f'Number of neutral labels: {np.sum(all_labels==1)}')
print(f'Number of positive labels: {np.sum(all_labels==2)}')
# Out:
# Number of instances: 1111
# Number of labels: 1111
# Number of negative labels: 310
# Number of neutral labels: 195
# Number of positive labels: 606

# %%
# Split the data into training, validation, testing sets.

from sklearn.model_selection import train_test_split

# Split test data from training data
train__docs, test__docs, train_labels, test_labels = train_test_split(
    all_text, 
    all_labels, 
    test_size=0.2, 
    stratify=all_labels
)

# Split validation data from training data
train__docs, val_documents, train_labels, val_labels = train_test_split(
    train__docs, 
    train_labels, 
    test_size=0.2, 
    stratify=train_labels
)

print(f'Number of training instances = {len(train__docs)}')
print(f'Number of validation instances = {len(val_documents)}')
print(f'Number of test instances = {len(test__docs)}')
# Out:
# Number of training instances = 710
# Number of validation instances = 178
# Number of test instances = 223

# %%
# Print example doc
print(f'What does one instance look like from the training set? \n\n{train__docs[234]}')
print(f'...and here is its corresponding label \n\n{train_labels[234]}')
# Out:
# What does one instance look like from the training set?
#
# EU regulators clear $100 billion-plus AB InBev, SABMiller deal
# ...and here is its corresponding label
#
# 2

# %% [markdown]
# # 1. Preprocessing using  lemmatization
# We create a lemmatizer tokenizer that reduces words to their root forms. This reduces the vocabulary size.

# %%
# We create a lemmaTokenizer class that applies lemmatization when tokenizing.
class LemmaTokenizer(object):
    
    def __init__(self):
        self.wnl = WordNetLemmatizer()
        
    def __call__(self, _docs):
        return [self.wnl.lemmatize(self.wnl.lemmatize(self.wnl.lemmatize(tok, pos='n'), pos='v'), pos='a') for tok in word_tokenize(_docs)]

# %% [markdown]
# # 2.1 Using bi-grams + unigrams as feature
# We apply our tokenizer and set it to allow ngram features (both unigrams and bigrams).

# %%
vectorizer = CountVectorizer(tokenizer=LemmaTokenizer(), ngram_range=(1,2))
vectorizer.fit(train__docs)
X_train = vectorizer.transform(train__docs)
X_val = vectorizer.transform(val_documents)
X_test__docs = vectorizer.transform(test__docs)
# Let's look at some of the features.
print(list(vectorizer.vocabulary_)[:10])
# Out:
# C:\Users\adnan\anaconda3\envs\data_analytics\lib\site-packages\sklearn\feature_extraction\text.py:516: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   warnings.warn(
# ['update', '3-bp', 'settle', 'oil', 'spill-related', 'claim', 'with', 'halliburton', ',', 'transocean']

# %%
# Checking full vocabulary size:
print(f' Full vocabulary size: {len(vectorizer.vocabulary_)}')
vocabulary = vectorizer.vocabulary_
# Out:
#  Full vocabulary size: 10597

# %%
# Now let's fit our data to the model.
classifier = LogisticRegression()
classifier.fit(X_train, train_labels)
y_val_pred = classifier.predict(X_val)
cm = confusion_matrix(val_labels, y_val_pred)
cm_display = ConfusionMatrixDisplay(cm).plot()
print(classification_report(val_labels, y_val_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.81      0.42      0.55        50
#            1       0.50      0.16      0.24        31
#            2       0.63      0.93      0.75        97
#
#     accuracy                           0.65       178
#    macro avg       0.65      0.50      0.52       178
# weighted avg       0.66      0.65      0.61       178

# %% [markdown]
# # Using POS-NEG lexicon features

# %%
# instantiate analyzer
analyser = SentimentIntensityAnalyzer()
# fetch vocabulary
vocabulary = vectorizer.vocabulary_
# create empy holders for lexicon scores.
lexicon_pos_scores = np.zeros((1, len(vocabulary)))
lexicon_neg_scores = np.zeros((1, len(vocabulary)))

for i, term in enumerate(vocabulary):
    if term in analyser.lexicon and analyser.lexicon[term] > 0:
        lexicon_pos_scores[0, i] = 1
    elif term in analyser.lexicon and analyser.lexicon[term] < 0:
        lexicon_neg_scores[0, i] = 1

# %%
# This enables us to get the total positive and total negative counts for each set:
lexicon_pos_train = np.sum(X_train.multiply(lexicon_pos_scores), axis=1)
lexicon_pos_val = np.sum(X_val.multiply(lexicon_pos_scores), axis=1)
lexicon_pos_test = np.sum(X_test__docs.multiply(lexicon_pos_scores), axis=1)

lexicon_neg_train = np.sum(X_train.multiply(lexicon_neg_scores), axis=1)
lexicon_neg_val = np.sum(X_val.multiply(lexicon_neg_scores), axis=1)
lexicon_neg_test = np.sum(X_test__docs.multiply(lexicon_neg_scores), axis=1)

# %%
X_train = hstack((X_train, lexicon_pos_train, lexicon_neg_train))
X_val = hstack((X_val, lexicon_pos_val, lexicon_neg_val))
X_test__docs = hstack((X_test__docs, lexicon_pos_test, lexicon_neg_test))

# %%
classifier = LogisticRegression()
classifier.fit(X_train, train_labels)
y_val_pred = classifier.predict(X_val)
# Checking performance
cm = confusion_matrix(val_labels, y_val_pred)
cm_display = ConfusionMatrixDisplay(cm).plot()
print(classification_report(val_labels, y_val_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.44      0.58        50
#            1       0.50      0.16      0.24        31
#            2       0.63      0.93      0.75        97
#
#     accuracy                           0.66       178
#    macro avg       0.66      0.51      0.53       178
# weighted avg       0.67      0.66      0.62       178

# %%
# Key part is investigating the errors by looking at the actual values, so let's do that:
error_indexes = y_val_pred != val_labels  # let's compare predictions to true values for labels

# get the _docs where the classifier made an error:
_docs_err = np.array(val_documents)[error_indexes]

pred_err = y_val_pred[error_indexes]
true_err = np.array(val_labels)[error_indexes]

for i in range(10):
    print(f'doc: {_docs_err[i]}; true label = {true_err[i]}, prediction = {pred_err[i]}.')
# Out:
# doc: InterContinental Hotels first-quarter global room revenue lags estimates; true label = 0, prediction = 2.
# doc: $AMZN trades in mid to upper range. No break out yet, either direction; true label = 1, prediction = 2.
# doc: $SPY Tomorrow party time for the Bears!! $GOOG and $MSFT -5.5%; true label = 0, prediction = 2.
# doc: AB InBev attacks SABMiller bid rebuffal; true label = 1, prediction = 2.
# doc: Standard Chartered lags on capital worries; true label = 0, prediction = 2.
# doc: $AAPL 620 resistance area; true label = 1, prediction = 2.
# doc: Centrica extends gas deals with Gazprom, Statoil; true label = 1, prediction = 2.
# doc: $SPY Don't hang your bull hat yet. Next week we will pop higher on QE3 hope on back of fed's 2 day meeting.; true label = 2, prediction = 0.
# doc: Mylan Appoints Ranjan Ray Chaudhuri as Global Commercial Lead for Mylan's Over ...; true label = 1, prediction = 2.
# doc: $AXDX I got bored, and took my proprietary profit exit. I didn't like the option liquidity and lousy spreads.; true label = 0, prediction = 2.

# %% [markdown]
# # Performance on test set

# %%
# Let's test the performance on the test set.
y_test_pred = classifier.predict(X_test__docs)
# Checking performance
cm = confusion_matrix(test_labels, y_test_pred)
cm_display = ConfusionMatrixDisplay(cm).plot()
print(classification_report(test_labels, y_test_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.67      0.42      0.51        62
#            1       0.44      0.21      0.28        39
#            2       0.64      0.88      0.74       122
#
#     accuracy                           0.63       223
#    macro avg       0.59      0.50      0.51       223
# weighted avg       0.62      0.63      0.60       223

# %% [markdown]
# # 4. Extracting topics using LDA

# %%
# First let's get another clean split of the data. 
from sklearn.model_selection import train_test_split

# Split test data from training data
train__docs, test__docs, train_labels, test_labels = train_test_split(
    all_text, 
    all_labels, 
    test_size=0.2, 
    stratify=all_labels
)

# Split validation data from training data
train__docs, val__docs, train_labels, val_labels = train_test_split(
    train__docs, 
    train_labels, 
    test_size=0.2, 
    stratify=train_labels 
)

print(f'Number of training instances = {len(train__docs)}')
print(f'Number of validation instances = {len(val__docs)}')
print(f'Number of test instances = {len(test__docs)}')
# Out:
# Number of training instances = 710
# Number of validation instances = 178
# Number of test instances = 223

# %%
 # We use the function below for tokenization. Does a number of things, including removing small words, deleting words with special chars,  changing uppercase to lowercase, and more.
def preprocess(text):
    final_results=[]
    for token in simple_preprocess(text) : 
        if token not in STOPWORDS:
            final_results.append(WordNetLemmatizer().lemmatize(token, 'v'))
    return final_results

# Create a list of preprocessed documents
processed = []
for doc in train__docs:
    processed.append(preprocess(doc))
print(processed)
# Out:
# [['fintech', 'provider', 'cafn', 'cachet', 'financial', 'solutions', 'surge', 'forward', 'today', 'post', 'earn', 'https', 'bj', 'csk', 'jkhy', 'fisv', 'momo'], ['hargreaves', 'lansdown', 'buck', 'weak', 'market', 'assets', 'rise', 'percent'], ['chessnwine', 'iwm', 'minute', 'chart', 'small', 'cap', 'threaten', 'descend', 'triangle', 'breakdown', 'http', 'stks', 'kkm'], ['hopeturock', 'yes', 'expectations', 'deal', 'somewhat', 'price', 'nice', 'pop', 'bid', 'come', 'higher', 'expect', 'yhoo'], ['break', 'tesla', 'recall', 'model', 'cars', 'detail', 'tsla'], ['cytx', 'look', 'like', 'ascend', 'channel', 'finfiz', 'http', 'stks'], ['louiebeene', 'vwap', 'hold', 'trend', 'line', 'lot', 'radars', 'navb'], ['tesla', 'motor', 'recall', 'model', 'suvs', 'tsla', 'https', 'dx', 'aegi'], ['lloyds', 'bank', 'group', 'share', 'price', 'lift', 'amid', 'report', 'bank', 'poise', 'axe', 'hundreds', 'uk', 'job'], ['rt', 'acinvestorblog', 'aapl', 'track'], ['thank', 'goog', 'google', 'alphabet', 'fb', 'facebook', 'stock', 'nice', 'reversal'], ['sbux', 'get', 'sell'], ['idcc', 'share', 'total', 'value', 'company', 'crunch', 'technology', 'diamond', 'rough'], ['ab', 'inbev', 'approach', 'sabmiller', 'explore', 'bn', 'tie'], ['maybe', 'close', 'aapl', 'call', 'morning', 'bad', 'idea', 'money', 'leave', 'table'], ['save', 'long', 'https', 'yejus', 'cmlc'], ['bad', 'idea', 'min', 'predictions', 'base', 'faith', 'rt', 'dandyduct', 'aapl', 'sell', 'signal', 'hit', 'min'], ['fb', 've', 'dead', 'far', 'bloat', 'valuation', 'https', 'czcf', 'kbrlt'], ['spy', 'vxx', 'aapl', 'party', 'load', 'uvxy', 'volatility'], ['apple', 'february', 'low', 'little', 'fanfare', 'aapl'], ['lnt', 'increase', 'annual', 'dividend', 'target', 'share', 'share'], ['fda', 'approve', 'astrazeneca', 'iressa', 'lung', 'cancer', 'treatment'], ['easyjet', 'expect', 'resilient', 'demand', 'withstand', 'security', 'fear'], ['cdti', 'bounce', 'support', 'setup', 'area', 'important', 'bull', 'lose', 'http', 'stks', 'mf'], ['look', 'amzn'], ['siriusxm', 'add', 'net', 'new', 'subscribers', 'quarter', 'siri', 'ceo', 'sales', 'marketresearch', 'tech', 'entrepreneur', 'speaker'], ['bbry', 'actually', 'lose', 'share', 'incl', 'vz', 'debt', 'cash'], ['entertainment', 'dispel', 'itv', 'takeover', 'rumour'], ['spain', 'caixabank', 'expect', 'close', 'deal', 'banco', 'bpi'], ['anheuser', 'busch', 'inbev', 'increase', 'offer', 'rival', 'sabmiller'], ['tsla', 'recall', 'big', 'deal', 'problem', 'excuse', 'guide', 'way', 'way', 'lower'], ['amzn', 'long', 'earn', 'look', 'good'], ['gild', 'support', 'ibb', 'bib', 'https', 'gioof', 'zbkv'], ['deutsche', 'bank', 'downgrade', 'starbucks', 'new', 'loyalty', 'program', 'https', 'iy', 'lcugabc', 'sbux'], ['sds', 'pick', 'speed', 'call', 'http', 'stks', 'eik', 'week', 'call', 'http', 'stks', 'eil'], ['ab', 'inbev', 'sell', 'sab', 'assets', 'seek', 'eu', 'deal', 'approval'], ['horizonte', 'acquire', 'neighbour', 'glencore', 'nickel', 'property', 'brazil'], ['update', 'pricey', 'beers', 'lift', 'sabmiller', 'quarterly', 'underlie', 'sales'], ['pierrules', 'siri', 'long'], ['nasdaq', 'set', 'breakout', 'ii', 'allstarcharts', 'http', 'stks', 'nv', 'goog', 'amzn', 'qcom'], ['inve', 'ya'], ['baird', 'like', 'tsla', 'upgrade', 'outperform', 'lift', 'price', 'target', 'research', 'firm', 'see', 'capital', 'raise', 'necessary', 'qtrs'], ['hk', 'jan', 'sink', 'ship'], ['ibio', 'premarket', 'ready', 'lift'], ['aks', 'dj', 'ak', 'steel', 'revenue', 'rise', 'auto', 'sector', 'demand', 'acquisition'], ['mcp', 'roll', 'new', 'intraday', 'low', 'pickers', 'continue', 'destroy'], ['companiestravis', 'perkins', 'lift', 'dividend', 'earn', 'rise'], ['nd', 'raise', 'year', 'bvhealthcare', 'qcor', 'questcor', 'increase', 'quarterly', 'cash', 'dividend', 'percent', 'http', 'stks', 'goan'], ['tsla', 'stock', 'gain', 'steam', 'plus', 'notable', 'move', 'week', 'https', 'hz', 'wdp', 'za'], ['agn', 'pypl', 'pressure', 'market', 'bullish', 'options', 'trade', 'morning', 'https', 'xg' ...

# %%
from gensim.corpora import Dictionary
# create a dictionary of word:id key/val pairs.
dictionary = Dictionary(processed) 
print(dictionary)

bow_corpus = [dictionary.doc2bow(doc) for doc in processed]
# Out:
# Dictionary(2320 unique tokens: ['bj', 'cachet', 'cafn', 'csk', 'earn']...)

# %%
# Getting means of thetas and training the LDA.



lda_model =  LdaModel(bow_corpus, 
                      num_topics=10, 
                      id2word=dictionary,                                    
                      passes=10,
                    ) 

def get_doc_topic_dists(_docs, lda_model):
    thetas = []
    for i in range(len(_docs)):
        # Get the doc
        unseen_doc = _docs[i]

        # Preprocess for bag of words:
        bow_vector = dictionary.doc2bow(preprocess(unseen_doc))

        # Let's get the topic distribution:
        theta_doc = lda_model[bow_vector]

        thetas.append(theta_doc)

    return thetas

thetas = get_doc_topic_dists(val__docs, lda_model)

# %%
# We will use colours to represent topics.
colours = ['blue', 'green', 'red', 'yellow', 'black', 'pink', 'purple',
           'orange',  'darkgreen',  'navy', 'crimson']

def convert_theta_sparse_to_dense_vector(theta_dist_sparse, num_topics):
    theta_dist = np.zeros(num_topics)
    
    # get active topics
    active_topics_for_dist, probs = map(list, zip(*theta_dist_sparse))
    
    # add to thetas_dist
    for i, topic in enumerate(active_topics_for_dist):
        if topic >= num_topics:
            break
            
        theta_dist[topic] = probs[i]
    
    return theta_dist

# Create barchart
def plot_theta(thetas, i, num__docs, num_topics):
    plt.subplot(int((num__docs+1)/2), 2, i+1)
    theta_dist = convert_theta_sparse_to_dense_vector(thetas[i], num_topics)
    plt.bar(x=np.arange(len(theta_dist)), height=theta_dist, color=colours, tick_label=np.arange(num_topics))
    plt.xlabel("Topic ID")
    plt.ylabel("Probability")
plt.figure(figsize=(20,20))

num__docs = 10
num_topics = 10
counter = 0
for i, theta in enumerate(thetas):
    if (counter < 10):
        plot_theta(thetas, i, num__docs, num_topics)
        counter +=1
plt.show()

# %% [markdown]
# # Visualizing topic distributions across labels using validation set

# %%
# Merge arrays for later 
arr = val__docs
arr_2 = val_labels

arrays = [arr,arr_2]
new_arr = np.stack(arrays, axis=1)
print(new_arr[new_arr[:,1] =='1'])
# Out:
# [['FDA panel backs safety updates for AstraZeneca, Takeda drugs' '1']
#  ['UPDATE 1-BP shareholders back more disclosure on climate change risks'
#   '1']
#  ['@technik I still have a smaller $GILD pos. Being very tender with cash due to volatility. So reluctant to keep many big positions.'
#   '1']
#  ["$RUSS Don't catch falling knives, but I think an entry is coming soon on this"
#   '1']
#  ["Barclays appoints JPMorgan's Paul Compton as new COO" '1']
#  ['Johnson Matthey profit falls but dividend rises' '1']
#  ['Royal Mail turnaround proving expensive in tough UK market' '1']
#  ['$RAD All my charts are flashing oversold.' '1']
#  ['Facebook, near a buy point last week, faces a different technical test today https://t.co/c72LLMpiNM $FB $AAPL $NFLX https://t.co/fPFbYTYPuY'
#   '1']
#  ['Shell offers 50 percent premium to buy BG for $70 billion' '1']
#  ['Breakingviews: IAG can pay more for Aer Lingus' '1']
#  ['Tesco sells Blinkbox and broadband service to TalkTalk' '1']
#  ['$RIG whos ever pushing this is crazy, get ready for suspended dividend (turning into growth stock) blow out earnings, and major buyback, lol'
#   '1']
#  ['UPDATE 3-BP settles oil spill-related claims with Halliburton, Transocean'
#   '1']
#  ["$HAL If bulls lucky enuff to get an upside gap fill, better take it. Wouldn't chase it here. http://stks.co/r12Us"
#   '1']
#  ['$COST Costco less than stellar day but it held the 50 day moving average'
#   '1']
#  ["CompaniesAB InBev signals it won't go hostile for SABMiller" '1']
#  ['Goodwin not to face Scottish prosecution over RBS' '1']
#  ['Irish housebuilder Cairn Homes plans London listing' '1']
#  ['$MPWR CEO sells 450k april 15th..meh' '1']
#  ['Goldman Sachs, Barclays, HSBC downplay Brexit threat' '1']
#  ['Tesco shareholders back ITV head for chairman' '1']
#  ['Shell challenges Exxon dominance with 47 billion-pound bid for BG' '1']
#  ['$YHOO fishy action. New party interested (DailyMail) bounce & retreats. Not short by any means, but action questions big up move. Thoughts?'
#   '1']
#  ['$MA http://stks.co/1CYN continues to consolidate / base here' '1']
#  ['Royal Mail gets mixed bag from Ofcom postal regulation report' '1']
#  ['$GILD Sandbagged the guidance so the can use that last 3 billion up.  CC was cautiously optimistic, wait til Next ER for confirmation'
#   '1']
#  ['$FAST $GWW - daily sales slowing again, pretty timely coincident indicator https://t.co/m6BKHBkzK5'
#   '1']
#  ['AB InBev attacks SABMiller bid rebuffal' '1']
#  ["Spain's Caixabank launches new takeover bid for Banco BPI" '1']
#  ['UPDATE: Barclays Expects Gain After Settling With Lehman Bros Trustee'
#   '1']]

# %%
# Show numbers till 8 decimal points for debugging.
np.set_printoptions(precision=8)
def get_doc_mean_topics():
    # Create a matrix where each row corresponds to a label
    mean_thetas = np.zeros((len(['0','1','2']), 10))
    label_arr = ['0','1','2']
    for label in label_arr:
        # call get_doc_topic_dists
        thetas_t_sparse = get_doc_topic_dists(val__docs[new_arr[:,1] ==label], lda_model)
        # convert to a dense vector
        thetas_t = []
        for theta_dist_t_sparse in thetas_t_sparse:
            if not theta_dist_t_sparse:
                continue
            thetas_dist = convert_theta_sparse_to_dense_vector(theta_dist_t_sparse, 10)
            thetas_t.append(thetas_dist)
        # Get the mean theta
        mean_theta_t = np.mean(thetas_t, axis=0)
        mean_thetas[int(label)] = mean_theta_t
        print(mean_thetas[int(label)])
    return mean_thetas
   
mean_arr = get_doc_mean_topics()

print(mean_arr.shape)
# Out:
# [0.19049292 0.13116719 0.07191368 0.07869586 0.09246759 0.15028958
#  0.06640199 0.09017522 0.07068672 0.05663177]
# [0.07159213 0.05638089 0.09693929 0.12406066 0.05456075 0.16360397
#  0.05781613 0.10714499 0.09560125 0.16754378]
# [0.09082363 0.09116909 0.07712473 0.08924359 0.08434557 0.11823605
#  0.07701655 0.13291564 0.09320408 0.14150402]
# (3, 10)

# %%
def plot_doc_topic_matrix():
    # Get mean doc topics dists
    mean_thetas = get_doc_mean_topics()
    # Let's show a heatmap to see which topics occur the most for different labels
    plt.imshow(mean_thetas)
    plt.colorbar()
    plt.xlabel("Topic ID")
    plt.ylabel("Class label")
    plt.show()
plot_doc_topic_matrix()
# Out:
# [0.19050501 0.13117263 0.05691277 0.07869041 0.09247362 0.1502854
#  0.06640575 0.09018045 0.08567093 0.05662557]
# [0.0715877  0.05637664 0.0969122  0.12406459 0.05456775 0.16363725
#  0.05781416 0.10713342 0.09560942 0.1675407 ]
# [0.10331505 0.09989941 0.08190426 0.08924428 0.0777121  0.11420706
#  0.07806839 0.12176247 0.09320698 0.13626295]

# %%
# For each topic, let's show the words occuring in that topic, so we can identify it.
for topic_id, topic in lda_model.print_topics(-1):
    print("Topic ID: {} \nAssociated Words:\n {}".format(topic_id, topic ))
    print("\n")
# Out:
# Topic ID: 0
# Associated Words:
#  0.019*"short" + 0.010*"https" + 0.010*"http" + 0.009*"time" + 0.009*"chart" + 0.009*"stock" + 0.008*"shire" + 0.007*"buy" + 0.007*"double" + 0.007*"tsla"
#
#
# Topic ID: 1
# Associated Words:
#  0.022*"https" + 0.017*"tsla" + 0.017*"recall" + 0.015*"model" + 0.012*"tesla" + 0.010*"stks" + 0.010*"http" + 0.009*"buy" + 0.008*"today" + 0.007*"seat"
#
#
# Topic ID: 2
# Associated Words:
#  0.015*"stks" + 0.015*"http" + 0.015*"long" + 0.014*"https" + 0.010*"break" + 0.010*"price" + 0.008*"sales" + 0.007*"look" + 0.007*"ready" + 0.006*"tsla"
#
#
# Topic ID: 3
# Associated Words:
#  0.018*"sales" + 0.017*"sabmiller" + 0.015*"inbev" + 0.013*"ab" + 0.012*"look" + 0.011*"today" + 0.009*"spy" + 0.009*"update" + 0.009*"rise" + 0.007*"sell"
#
#
# Topic ID: 4
# Associated Words:
#  0.024*"share" + 0.010*"price" + 0.010*"fb" + 0.009*"market" + 0.008*"close" + 0.008*"look" + 0.008*"standard" + 0.007*"glencore" + 0.007*"stock" + 0.007*"https"
#
#
# Topic ID: 5
# Associated Words:
#  0.046*"http" + 0.045*"stks" + 0.014*"chart" + 0.010*"aapl" + 0.009*"support" + 0.008*"short" + 0.008*"spy" + 0.006*"https" + 0.005*"buy" + 0.005*"rt"
#
#
# Topic ID: 6
# Associated Words:
#  0.014*"bank" + 0.009*"stks" + 0.009*"http" + 0.008*"sbux" + 0.007*"aviva" + 0.006*"deutsche" + 0.006*"https" + 0.006*"today" + 0.006*"hod" + 0.006*"new"
#
#
# Topic ID: 7
# Associated Words:
#  0.016*"buy" + 0.015*"https" + 0.013*"stock" + 0.011*"fb" + 0.009*"tsla" + 0.008*"nice" + 0.007*"aapl" + 0.007*"hold" + 0.006*"short" + 0.006*"like"
#
#
# Topic ID: 8
# Associated Words:
#  0.015*"https" + 0.010*"good" + 0.007*"buy" + 0.007*"long" + 0.007*"oil" + 0.006*"sales" + 0.006*"get" + 0.006*"today" + 0.005*"look" + 0.004*"aapl"
#
#
# Topic ID: 9
# Associated Words:
#  0.018*"aapl" + 0.015*"price" + 0.014*"share" + 0.012*"deal" + 0.010*"long" + 0.008*"sell" + 0.007*"shell" + 0.007*"bg" + 0.006*"right" + 0.006*"drug"

# %% [markdown]
# # Using test set

# %%
# Merge arrays for later 
arr = test__docs
arr_2 = test_labels

arrays = [arr,arr_2]
new_arr = np.stack(arrays, axis=1)
print(new_arr[new_arr[:,1] =='1'])

# Show numbers till 8 decimal points for debugging.
np.set_printoptions(precision=8)
def get_doc_mean_topics():
    # Create a matrix where each row corresponds to a label
    mean_thetas = np.zeros((len(['0','1','2']), 10))
    label_arr = ['0','1','2']
    for label in label_arr:
        # call get_doc_topic_dists
        thetas_t_sparse = get_doc_topic_dists(test__docs[new_arr[:,1] ==label], lda_model)
        # convert to a dense vector
        thetas_t = []
        for theta_dist_t_sparse in thetas_t_sparse:
            if not theta_dist_t_sparse:
                continue
            thetas_dist = convert_theta_sparse_to_dense_vector(theta_dist_t_sparse, 10)
            thetas_t.append(thetas_dist)
        # Get the mean theta
        mean_theta_t = np.mean(thetas_t, axis=0)
        mean_thetas[int(label)] = mean_theta_t
        print(mean_thetas[int(label)])
    return mean_thetas
   
mean_arr = get_doc_mean_topics()

def plot_doc_topic_matrix():
    # Get mean doc topics dists
    mean_thetas = get_doc_mean_topics()
    # Let's show a heatmap to see which topics occur the most for different labels
    plt.imshow(mean_thetas)
    plt.colorbar()
    plt.xlabel("Topic ID")
    plt.ylabel("Class label")
    plt.show()
plot_doc_topic_matrix()
# Out:
# [['$AAPL at pivot area on intraday chart- break here could send this to 50-day SMA, 457.80 http://stks.co/jPbN'
#   '1']
#  ['Saudi Aramco, Shell plan to break up Motiva, divide up assets' '1']
#  ['RT @StockTwits RT @fallondpicks Breadth Consolidates: After weeks of steady gains,advances in mkt breadth slowe... http://stks.co/2TrG $QQQ'
#   '1']
#  ['volatility squeeze in $AAPL. I hope it gets resolved to the upside'
#   '1']
#  ["$XLI Potential intermediate top in an Uptrend on a 60'-15'-4' charts http://stks.co/j1TdF"
#   '1']
#  ['$UBNT still having some trouble at the resistance line. Should resolve soon.@cheri1 @strattonite   http://stks.co/c0sU4'
#   '1']
#  ['MarketsBP promotes upstream boss to deputy CEO' '1']
#  ['Bilfinger Industrial Services win Â£100m BP contract extension' '1']
#  ['$AAPL Action into the close indicates that $AAPL probably hit a near term high.  Momentum slowing after a huge run.'
#   '1']
#  ['Barclays poised to replace Sir Mike Rake as he heads for exit' '1']
#  ["RT @jan $ARNA Don't think buyout rumor strong enough too be driving this up just yet...when it is this may fly like aapl...// fly how high?"
#   '1']
#  ['Philip Morris, BAT Sue Over Law Taking Branding Off Packs' '1']
#  ['Petrofac share price rises despite Â£30m costs on North Sea project'
#   '1']
#  ['$AAPL a new long IF 110.61 is broken. Targets are 112.19, 119.86 & 123.82. Bears must retake 102.77. $QQQ $NQ_F $NDX https://t.co/6l3m1wXChw'
#   '1']
#  ['Tesco sells half of stake in ecommerce site Lazada to Alibaba for Â£90m'
#   '1']
#  ['Should You Buy Jumbo Yielders British American Tobacco plc, Centrica PLC & John Wood Group PLC?'
#   '1']
#  ['$AAPL 620 resistance area' '1']
#  ['Ocwen Reaches Settlement With California Regulator' '1']
#  ['Adobe Receives New Rating from Top Analyst $ADBE https://t.co/LJNXPEvHZN'
#   '1']
#  ['Randgold profit hit by poor gold price but dividend still increases'
#   '1']
#  ['$CNP Sell Short Position on CNP,...Closed for Profit $ 59,367.00 (7.75%) http://stks.co/ghjc'
#   '1']
#  ['Coke dividend - 3%. Google dividend - 0%. For passive income Coke takes it. $GOOG $KO https://t.co/QBsoWjxOST'
#   '1']
#  ['UPDATE: CIB, Legal & General Sell Egyptian Life Joint Venture To AXA'
#   '1']
#  ["CompaniesHome Retail trims gains but is considered 'in play'" '1']
#  ['ConAgra Names Former Hillshire Farms CEO Connolly to Top Post' '1']
#  ['UPDATE 1-Engineering firm Smiths Group confirms CEO appointment' '1']
#  ["New Morrisons duo get former boss's support to diffuse investor tension"
#   '1']
#  ["My $DWA play up 6% today. I'm still skeptical. Will take profits. Not a time cheer"
#   '1']
#  ['$aapl short term fund/redemption liquidations.. Should have the channel cleared soon and on solid footing. $520 is new floor come July! :)'
#   '1']
#  ['Valeant Said to Name New CEO With Pearson Still Hospitalized' '1']
#  ['Ackman, in email, says supports Valeant CEO Pearson' '1']
#  ["Warren Buffett defends Berkshire Hathaway's conglomerate structure"
#   '1']
#  ['Carnival Corporation and China Merchants Group Sign Memo of Understanding ...'
#   '1']
#  ["Credit Suisse poaches Prudential's Thiam for Asian push" '1']
#  ['$AAPL bounce right now has no vol, more vol when it slid' '1']
#  ['$QCOR a little pullback is fine but if this erases all of todays gains, I cannot believe the manipulation its capable of'
#   '1']
#  ['InterContinental Hotels Denies Reports of Starwood Merger Talks' '1']
#  ['$SLW is down, but weekly $34 calls (-28.95%), .23 x .25 have 321 volume. Worth a chance here, jmho: http://stks.co/1Qfg'
#   '1']
#  ["Mylan Appoints Ranjan Ray Chaudhuri as Global Commercial Lead for Mylan's Over ..."
#   '1']]
# [0.11054327 0.11667616 0.10424824 0.05505205 0.10289099 0.13855789
#  0.105181   0.11478191 0.05830839 0.0870867 ]
# [0.10645384 0.07118758 0.06877293 0.08233793 0.07055415 0.23807353
#  0.08960798 0.07935737 0.06348417 0.12275096]
# [0.1144614  0.07574273 0.09276616 0.09157741 0.10076057 0.17416231
#  0.06970183 0.10082574 0.06637929 0.10857194]
# [0.10864682 0.13727317 0.10433492 0.05505191 0.10113346 0.13290594
#  0.1030466  0.10358655 0.06020139 0.08702165]
# [0.10952971 0.07271181 0.07477074 0.07760658 0.06864053 0.23307894
#  0.08224547 0.0836341  0.06763051 0.12273203]
# [0.11253782 0.0823769  0.08949341 0.09203109 0.09962839 0.17351815
#  0.06897979 0.10145351 0.0663805  0.10854979]
